# %%
import pandas as pd
from settings import KOREAN_BANK_SECRET_KEY
import requests
import json
url = 'http://ecos.bok.or.kr/api/StatisticTableList/{}/json/kr/1/10000/'.format(KOREAN_BANK_SECRET_KEY)
data = requests.get(url)
jsonData = json.loads(data.text)

# %%
from utils import search_stats_code
search_stats_code(jsonData,'금리')
# Out:
# {'status': 'SUCCESS',
#  'data': [{'SRCH_YN': 'N',
#    'ORG_NAME': '',
#    'CYCLE': '',
#    'STAT_NAME': '2.한국은행 주요계정 및 기준금리',
#    'STAT_CODE': '000Y055',
#    'P_STAT_CODE': '*'},
#   {'SRCH_YN': 'Y',
#    'ORG_NAME': '',
#    'CYCLE': 'DD',
#    'STAT_NAME': '2.6.한국은행 기준금리 및 여수신금리',
#    'STAT_CODE': '098Y001',
#    'P_STAT_CODE': '000Y055'},
#   {'SRCH_YN': 'N',
#    'ORG_NAME': '',
#    'CYCLE': '',
#    'STAT_NAME': '4.1.시장금리',
#    'STAT_CODE': '000Y077',
#    'P_STAT_CODE': '000Y008'},
#   {'SRCH_YN': 'Y',
#    'ORG_NAME': '',
#    'CYCLE': 'DD',
#    'STAT_NAME': '4.1.1 시장금리(일별)',
#    'STAT_CODE': '060Y001',
#    'P_STAT_CODE': '000Y077'},
#   {'SRCH_YN': 'Y',
#    'ORG_NAME': '',
#    'CYCLE': 'MM',
#    'STAT_NAME': '4.1.2 시장금리(월,분기,년)',
#    'STAT_CODE': '028Y001',
#    'P_STAT_CODE': '000Y077'},
#   {'SRCH_YN': 'N',
#    'ORG_NAME': '',
#    'CYCLE': '',
#    'STAT_NAME': '4.2.예금은행  가중평균금리',
#    'STAT_CODE': '000Y078',
#    'P_STAT_CODE': '000Y008'},
#   {'SRCH_YN': 'N',
#    'ORG_NAME': '',
#    'CYCLE': '',
#    'STAT_NAME': '4.2.1 수신금리',
#    'STAT_CODE': '000Y091',
#    'P_STAT_CODE': '000Y078'},
#   {'SRCH_YN': 'N',
#    'ORG_NAME': '',
#    'CYCLE': '',
#    'STAT_NAME': '4.2.2 대출금리',
#    'STAT_CODE': '000Y092',
#    'P_STAT_CODE': '000Y078'},
#   {'SRCH_YN': 'Y',
#    'ORG_NAME': '',
#    'CYCLE': 'MM',
#    'STAT_NAME': '4.3.예금은행 금리수준별 여수신 비중',
#    'STAT_CODE': '005Y010',
#    'P_STAT_CODE': '000Y008'},
#   {'SRCH_YN': 'N',
#    'ORG_NAME': '',
#    'CYCLE': '',
#    'STAT_NAME': '4.4.예금은행 고정 및 특정 금리연동대출 비중',
#    'STAT_CODE': '000Y119',
#    'P_STAT_CODE': '000Y008'},
#   {'SRCH_YN': 'N',
#    'ORG_NAME': '',
#    'CYCLE': '',
#    'STAT_NAME': '4.5.비은행금융기관  가중평균금리',
#    'STAT_CODE': '000Y079',
#    'P_STAT_CODE': '000Y008'},
#   {'SRCH_YN': 'Y',
#    'ORG_NAME': '',
#    'CYCLE': 'MM',
#    'STAT_NAME': '4.5.1 수신금리(신규취급액기준)',
#    'STAT_CODE': '005Y002',
#    'P_STAT_CODE': '000Y079'},
#   {'SRCH_YN': 'Y',
#    'ORG_NAME': '',
#    'CYCLE': 'MM',
#    'STAT_NAME': '4.5.2 대출금리(신규취급액기준)',
#    'STAT_CODE': '005Y004',
#    'P_STAT_CODE': '000Y079'},
#   {'SRCH_YN': 'Y',
#    'ORG_NAME': '',
#    'CYCLE': 'MM',
#    'STAT_NAME': '18.1.5 주요국제금리',
#    'STAT_CODE': 'I04Y005',
#    'P_STAT_CODE': '000Y070'}]}

# %%
url = 'http://ecos.bok.or.kr/api/StatisticItemList/{}/json/kr/1/10000/{}/'.format(KOREAN_BANK_SECRET_KEY,'060Y001')
response = requests.get(url)
data = response.text
data = json.loads(data)

# %%
search_stats_code(data,'회사채','ITEM_NAME')
# Out:
# {'status': 'SUCCESS',
#  'data': [{'END_TIME': '20181001',
#    'DATA_CNT': 6088,
#    'GRP_NAME': 'Group1',
#    'CYCLE': 'DD',
#    'STAT_NAME': '4.1.1 시장금리(일별)',
#    'ITEM_NAME': '회사채(3년,AA-)',
#    'STAT_CODE': '060Y001',
#    'ITEM_CODE': '010300000',
#    'START_TIME': '19950103'},
#   {'END_TIME': '20181001',
#    'DATA_CNT': 4565,
#    'GRP_NAME': 'Group1',
#    'CYCLE': 'DD',
#    'STAT_NAME': '4.1.1 시장금리(일별)',
#    'ITEM_NAME': '회사채(3년)(BBB-)',
#    'STAT_CODE': '060Y001',
#    'ITEM_CODE': '010320000',
#    'START_TIME': '19950103'},
#   {'END_TIME': '20181001',
#    'DATA_CNT': 4007,
#    'GRP_NAME': 'Group1',
#    'CYCLE': 'DD',
#    'STAT_NAME': '4.1.1 시장금리(일별)',
#    'ITEM_NAME': '회사채(AA-, 민평)수익률',
#    'STAT_CODE': '060Y001',
#    'ITEM_CODE': '010310000',
#    'START_TIME': '19950103'}]}

# %%
from datetime import timedelta, date
import requests 
def daterange(start_date, end_date,diffrange):
    date_diff = (end_date - start_date).days
    for n in range(0,int(date_diff),diffrange):
        start = start_date + timedelta(n)
        if n + (diffrange -1) < date_diff:
            end = start_date + timedelta(n+(diffrange -1))
        else:
            end = start_date + timedelta(date_diff)
        yield start, end 

        

start_date = date(2013, 1, 1)
end_date = date(2015, 6, 2)
for single_date in daterange(start_date, end_date,10):
    print(single_date)
url = 'http://ecos.bok.or.kr/api/StatisticSearch/sample/json/kr/0/10/060Y001/DD/19950103/20181001/010300000/'
response = requests.get(url)
data = response.text
# Out:
# (datetime.date(2013, 1, 1), datetime.date(2013, 1, 10))
# (datetime.date(2013, 1, 11), datetime.date(2013, 1, 20))
# (datetime.date(2013, 1, 21), datetime.date(2013, 1, 30))
# (datetime.date(2013, 1, 31), datetime.date(2013, 2, 9))
# (datetime.date(2013, 2, 10), datetime.date(2013, 2, 19))
# (datetime.date(2013, 2, 20), datetime.date(2013, 3, 1))
# (datetime.date(2013, 3, 2), datetime.date(2013, 3, 11))
# (datetime.date(2013, 3, 12), datetime.date(2013, 3, 21))
# (datetime.date(2013, 3, 22), datetime.date(2013, 3, 31))
# (datetime.date(2013, 4, 1), datetime.date(2013, 4, 10))
# (datetime.date(2013, 4, 11), datetime.date(2013, 4, 20))
# (datetime.date(2013, 4, 21), datetime.date(2013, 4, 30))
# (datetime.date(2013, 5, 1), datetime.date(2013, 5, 10))
# (datetime.date(2013, 5, 11), datetime.date(2013, 5, 20))
# (datetime.date(2013, 5, 21), datetime.date(2013, 5, 30))
# (datetime.date(2013, 5, 31), datetime.date(2013, 6, 9))
# (datetime.date(2013, 6, 10), datetime.date(2013, 6, 19))
# (datetime.date(2013, 6, 20), datetime.date(2013, 6, 29))
# (datetime.date(2013, 6, 30), datetime.date(2013, 7, 9))
# (datetime.date(2013, 7, 10), datetime.date(2013, 7, 19))
# (datetime.date(2013, 7, 20), datetime.date(2013, 7, 29))
# (datetime.date(2013, 7, 30), datetime.date(2013, 8, 8))
# (datetime.date(2013, 8, 9), datetime.date(2013, 8, 18))
# (datetime.date(2013, 8, 19), datetime.date(2013, 8, 28))
# (datetime.date(2013, 8, 29), datetime.date(2013, 9, 7))
# (datetime.date(2013, 9, 8), datetime.date(2013, 9, 17))
# (datetime.date(2013, 9, 18), datetime.date(2013, 9, 27))
# (datetime.date(2013, 9, 28), datetime.date(2013, 10, 7))
# (datetime.date(2013, 10, 8), datetime.date(2013, 10, 17))
# (datetime.date(2013, 10, 18), datetime.date(2013, 10, 27))
# (datetime.date(2013, 10, 28), datetime.date(2013, 11, 6))
# (datetime.date(2013, 11, 7), datetime.date(2013, 11, 16))
# (datetime.date(2013, 11, 17), datetime.date(2013, 11, 26))
# (datetime.date(2013, 11, 27), datetime.date(2013, 12, 6))
# (datetime.date(2013, 12, 7), datetime.date(2013, 12, 16))
# (datetime.date(2013, 12, 17), datetime.date(2013, 12, 26))
# (datetime.date(2013, 12, 27), datetime.date(2014, 1, 5))
# (datetime.date(2014, 1, 6), datetime.date(2014, 1, 15))
# (datetime.date(2014, 1, 16), datetime.date(2014, 1, 25))
# (datetime.date(2014, 1, 26), datetime.date(2014, 2, 4))
# (datetime.date(2014, 2, 5), datetime.date(2014, 2, 14))
# (datetime.date(2014, 2, 15), datetime.date(2014, 2, 24))
# (datetime.date(2014, 2, 25), datetime.date(2014, 3, 6))
# (datetime.date(2014, 3, 7), datetime.date(2014, 3, 16))
# (datetime.date(2014, 3, 17), datetime.date(2014, 3, 26))
# (datetime.date(2014, 3, 27), datetime.date(2014, 4, 5))
# (datetime.date(2014, 4, 6), datetime.date(2014, 4, 15))
# (datetime.date(2014, 4, 16), datetime.date(2014, 4, 25))
# (datetime.date(2014, 4, 26), datetime.date(2014, 5, 5))
# (datetime.date(2014, 5, 6), datetime.date(2014, 5, 15))
# (datetime.date(2014, 5, 16), datetime.date(2014, 5, 25))
# (datetime.date(2014, 5, 26), datetime.date(2014, 6, 4))
# (datetime.date(2014, 6, 5), datetime.date(2014, 6, 14))
# (datetime.date(2014, 6, 15), datetime.date(2014, 6, 24))
# (datetime.date(2014, 6, 25), datetime.date(2014, 7, 4))
# (datetime.date(2014, 7, 5), datetime.date(2014, 7, 14))
# (datetime.date(2014, 7, 15), datetime.date(2014, 7, 24))
# (datetime.date(2014, 7, 25), datetime.date(2014, 8, 3))
# (datetime.date(2014, 8, 4), datetime.date(2014, 8, 13))
# (datetime.date(2014, 8, 14), datetime.date(2014, 8, 23))
# (datetime.date(2014, 8, 24), datetime.date(2014, 9, 2))
# (datetime.date(2014, 9, 3), datetime.date(2014, 9, 12))
# (datetime.date(2014, 9, 13), datetime.date(2014, 9, 22))
# (datetime.date(2014, 9, 23), datetime.date(2014, 10, 2))
# (datetime.date(2014, 10, 3), datetime.date(2014, 10, 12))
# (datetime.date(2014, 10, 13), datetime.date(2014, 10, 22))
# (datetime.date(2014, 10, 23), datetime.date(2014, 11, 1))
# (datetime.date(2014, 11, 2), datetime.date(2014, 11, 11))
# (datetime.date(2014, 11, 12), datetime.date(2014, 11, 21))
# (datetime.date(2014, 11, 22), datetime.date(2014, 12, 1))
# (datetime.date(2014, 12, 2), datetime.date(2014, 12, 11))
# (datetime.date(2014, 12, 12), datetime.date(2014, 12, 21))
# (datetime.date(2014, 12, 22), datetime.date(2014, 12, 31))
# (datetime.date(2015, 1, 1), datetime.date(2015, 1, 10))
# (datetime.date(2015, 1, 11), datetime.date(2015, 1, 20))
# (datetime.date(2015, 1, 21), datetime.date(2015, 1, 30))
# (datetime.date(2015, 1, 31), datetime.date(2015, 2, 9))
# (datetime.date(2015, 2, 10), datetime.date(2015, 2, 19))
# (datetime.date(2015, 2, 20), datetime.date(2015, 3, 1))
# (datetime.date(2015, 3, 2), datetime.date(2015, 3, 11))
# (datetime.date(2015, 3, 12), datetime.date(2015, 3, 21))
# (datetime.date(2015, 3, 22), datetime.date(2015, 3, 31))
# (datetime.date(2015, 4, 1), datetime.date(2015, 4, 10))
# (datetime.date(2015, 4, 11), datetime.date(2015, 4, 20))
# (datetime.date(2015, 4, 21), datetime.date(2015, 4, 30))
# (datetime.date(2015, 5, 1), datetime.date(2015, 5, 10))
# (datetime.date(2015, 5, 11), datetime.date(2015, 5, 20))
# (datetime.date(2015, 5, 21), datetime.date(2015, 5, 30))
# (datetime.date(2015, 5, 31), datetime.date(2015, 6, 2))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-483500ab370a> in <module>()
#      20 response = requests.get(url)
#      21 data = response.text
# ---> 22 data = json.loads(data)
#
# NameError: name 'json' is not defined

# %%
import json 
data = json.loads(data)

# %%
data
# Out:
# {'StatisticSearch': {'list_total_count': 6088,
#   'row': [{'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.25',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950103'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.3',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950104'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.42',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950105'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.45',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950106'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.45',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950107'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.45',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950109'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.47',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950110'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.5',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950111'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '14.67',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950112'},
#    {'UNIT_NAME': '연%',
#     'STAT_NAME': '4.1.1 시장금리(일별)',
#     'ITEM_CODE1': '010300000',
#     'STAT_CODE': '060Y001',
#     'ITEM_CODE2': ' ',
#     'ITEM_CODE3': ' ',
#     'ITEM_NAME1': '회사채(3년,AA-)',
#     'ITEM_NAME2': ' ',
#     'DATA_VALUE': '15',
#     'ITEM_NAME3': ' ',
#     'TIME': '19950113'}]}}

# %%
x = []
x.extend(map(lambda x : float(x['DATA_VALUE']),data['StatisticSearch']['row']))

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.support import expected_conditions as EC
industry_list = {}
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
driver = webdriver.Chrome('./chromedriver',chrome_options=chrome_options)
driver.implicitly_wait(10)
indust_lst = []
try:
    driver.get('http://finance.daum.net/quote/upjong.daum?nil_stock=refresh')
    driver.switch_to.frame(driver.find_element_by_xpath("//iframe"))
    classButtonXpath= "//*[@id='bizBody1']"
    iframeTable = driver.find_element_by_xpath(classButtonXpath)
    tr_lst = iframeTable.find_elements_by_xpath('//tr')
    for tr in tr_lst:
        try:
            html_source = tr.get_attribute('innerHTML')
            soup = BeautifulSoup(html_source)
            td = soup.find('td',{'class':'txt'})
            a = td.find('a')
            site = a['href']
            name = td.text 
            siteData = {}
            siteData['name'] = name 
            siteData['site'] = site
            indust_lst.append(siteData)
        except Exception as e2:
            pass 

except Exception as e :
    print(str(e))
    pass
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: use options instead of chrome_options
#   if __name__ == '__main__':

# %%
import json 
with open('industList.json', 'w') as outfile:
    json.dump(indust_lst, outfile, sort_keys=True, indent=4)

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import json
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
driver = webdriver.Chrome('./chromedriver',chrome_options=chrome_options)
driver.implicitly_wait(5)
companyList = []
htmlList = []


def get_company_names(html_source,companyList,industry):
    soup = BeautifulSoup(html_source)
    tableElem = soup.find('table',{'class':"gTable"})
    if tableElem: 
        tdList = tableElem.findAll('td',{'class':'txt'})
        for td in tdList:
            try:
                a = td.find('a')
                site = a['href']
                companyName = td.text 
                siteData = {}
                siteData['name'] = companyName 
                siteData['code'] = site
                siteData['industry'] = industry
                companyList.append(siteData)
            except Exception as e:
                print(e)
                pass 
    return companyList

def getScriptList(driver):
    scriptList = []
    pageXpath= "//*[@class='pagingTable']"
    paginationTable = driver.find_element_by_xpath(pageXpath)
    if paginationTable:
        paginationElements = paginationTable.find_elements_by_xpath('//tr/td/span')
        for idx,pageButton in enumerate(paginationElements): 
            htmlSource = pageButton.get_attribute('innerHTML')
            if 'href' in htmlSource:
                aTag = pageButton.find_element_by_tag_name('a')
                script = aTag.get_attribute('href')
                scriptList.append(script)
    return scriptList

    
with open('industList.json') as data_file:    
    indust_lst = json.load(data_file)
    
for ind in indust_lst:
    baseUrl ='http://finance.daum.net'
    url = baseUrl + ind['site']
    industry = ind['name']
    driver.get(url)
    driver.switch_to.frame(driver.find_element_by_xpath("//iframe"))
    html_source = driver.page_source
    companyList = get_company_names(html_source,companyList,industry)
    scriptList = getScriptList(driver)
    for script in scriptList:
        driver.execute_script(script)
        html_source = driver.page_source
        companyList = get_company_names(html_source,companyList,industry)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
import json 
with open('companyList.json', 'w') as outfile:
    json.dump(companyList, outfile, sort_keys=True, indent=4)

# %%
from koreabank.bank_handler import BankHandler
import pandas as pd 
bh = BankHandler()
data = bh.get_daily_stats('20180103', '20181001', '060Y001', '010300000')
# Out:
# /usr/local/lib/python3.7/site-packages/grequests.py:21: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.contrib.pyopenssl (/usr/local/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py)', 'urllib3.util (/usr/local/lib/python3.7/site-packages/urllib3/util/__init__.py)'].
#   curious_george.patch_all(thread=False, select=False)

# %%
df= pd.DataFrame(data)

# %%
from datetime import timedelta, date
from datetime import datetime as dt

def daterange(start_date_str, end_date_str, diffrange):
    start_date = dt.strptime(start_date_str, '%Y%m%d').date()
    end_date = dt.strptime(end_date_str, '%Y%m%d').date()
    date_diff = (end_date - start_date).days
    for n in range(0, int(date_diff), diffrange):
        start = start_date + timedelta(n)
        if n + (diffrange - 1) < date_diff:
            end = start_date + timedelta(n+(diffrange - 1))
        else:
            end = start_date + timedelta(date_diff)
        yield start.strftime('%Y%m%d'), end.strftime('%Y%m%d')
for i in daterange('20100101','20101001',10):
    print(i)
# Out:
# ('20100101', '20100110')
# ('20100111', '20100120')
# ('20100121', '20100130')
# ('20100131', '20100209')
# ('20100210', '20100219')
# ('20100220', '20100301')
# ('20100302', '20100311')
# ('20100312', '20100321')
# ('20100322', '20100331')
# ('20100401', '20100410')
# ('20100411', '20100420')
# ('20100421', '20100430')
# ('20100501', '20100510')
# ('20100511', '20100520')
# ('20100521', '20100530')
# ('20100531', '20100609')
# ('20100610', '20100619')
# ('20100620', '20100629')
# ('20100630', '20100709')
# ('20100710', '20100719')
# ('20100720', '20100729')
# ('20100730', '20100808')
# ('20100809', '20100818')
# ('20100819', '20100828')
# ('20100829', '20100907')
# ('20100908', '20100917')
# ('20100918', '20100927')
# ('20100928', '20101001')

# %%
company_lst
# Out:
# [{'code': '032640.KS', 'industry': '통신업', 'name': 'LG유플러스'},
#  {'code': '017670.KS', 'industry': '통신업', 'name': 'SK텔레콤'},
#  {'code': '030200.KS', 'industry': '통신업', 'name': 'KT'},
#  {'code': '006490.KS', 'industry': '통신업', 'name': '인스코비'},
#  {'code': '000810.KS', 'industry': '보험업', 'name': '삼성화재'},
#  {'code': '001450.KS', 'industry': '보험업', 'name': '현대해상'},
#  {'code': '005830.KS', 'industry': '보험업', 'name': 'DB손해보험'},
#  {'code': '000370.KS', 'industry': '보험업', 'name': '한화손해보험'},
#  {'code': '003690.KS', 'industry': '보험업', 'name': '코리안리'},
#  {'code': '032830.KS', 'industry': '보험업', 'name': '삼성생명'},
#  {'code': '088350.KS', 'industry': '보험업', 'name': '한화생명'},
#  {'code': '085620.KS', 'industry': '보험업', 'name': '미래에셋생명'},
#  {'code': '000400.KS', 'industry': '보험업', 'name': '롯데손해보험'},
#  {'code': '000540.KS', 'industry': '보험업', 'name': '흥국화재'},
#  {'code': '000815.KS', 'industry': '보험업', 'name': '삼성화재우'},
#  {'code': '000547.KS', 'industry': '보험업', 'name': '흥국화재2우B'},
#  {'code': '082640.KS', 'industry': '보험업', 'name': '동양생명'},
#  {'code': '000545.KS', 'industry': '보험업', 'name': '흥국화재우'},
#  {'code': '000060.KS', 'industry': '보험업', 'name': '메리츠화재'},
#  {'code': '079440.KS', 'industry': '보험업', 'name': '오렌지라이프'},
#  {'code': '024110.KS', 'industry': '은행', 'name': '기업은행'},
#  {'code': '000030.KS', 'industry': '은행', 'name': '우리은행'},
#  {'code': '192530.KS', 'industry': '은행', 'name': '광주은행'},
#  {'code': '006220.KS', 'industry': '은행', 'name': '제주은행'},
#  {'code': '007540.KS', 'industry': '금융업', 'name': '샘표'},
#  {'code': '004990.KS', 'industry': '금융업', 'name': '롯데지주'},
#  {'code': '000810.KS', 'industry': '금융업', 'name': '삼성화재'},
#  {'code': '096775.KS', 'industry': '금융업', 'name': 'SK이노베이션'},
#  {'code': '044820.KS', 'industry': '금융업', 'name': '코스맥스비티아'},
#  {'code': '00499K.KS', 'industry': '금융업', 'name': '롯데지주우'},
#  {'code': '096770.KS', 'industry': '금융업', 'name': 'SK이노베이션'},
#  {'code': '003470.KS', 'industry': '금융업', 'name': '유안타증권'},
#  {'code': '058650.KS', 'industry': '금융업', 'name': '세아홀딩스'},
#  {'code': '001450.KS', 'industry': '금융업', 'name': '현대해상'},
#  {'code': '086790.KS', 'industry': '금융업', 'name': '하나금융지주'},
#  {'code': '009970.KS', 'industry': '금융업', 'name': '영원무역홀딩스'},
#  {'code': '078930.KS', 'industry': '금융업', 'name': 'GS'},
#  {'code': '024110.KS', 'industry': '금융업', 'name': '기업은행'},
#  {'code': '001800.KS', 'industry': '금융업', 'name': '오리온홀딩스'},
#  {'code': '006880.KS', 'industry': '금융업', 'name': '신송홀딩스'},
#  {'code': '005830.KS', 'industry': '금융업', 'name': 'DB손해보험'},
#  {'code': '180640.KS', 'industry': '금융업', 'name': '한진칼'},
#  {'code': '000370.KS', 'industry': '금융업', 'name': '한화손해보험'},
#  {'code': '034730.KS', 'industry': '금융업', 'name': 'SK'},
#  {'code': '008930.KS', 'industry': '금융업', 'name': '한미사이언스'},
#  {'code': '001940.KS', 'industry': '금융업', 'name': 'KISCO홀딩'},
#  {'code': '003690.KS', 'industry': '금융업', 'name': '코리안리'},
#  {'code': '001200.KS', 'industry': '금융업', 'name': '유진투자증권'},
#  {'code': '267250.KS', 'industry': '금융업', 'name': '현대중공업지주'},
#  {'code': '032830.KS', 'industry': '금융업', 'name': '삼성생명'},
#  {'code': '088350.KS', 'industry': '금융업', 'name': '한화생명'},
#  {'code': '016880.KS', 'industry': '금융업', 'name': '웅진'},
#  {'code': '001630.KS', 'industry': '금융업', 'name': '종근당홀딩스'},
#  {'code': '003480.KS', 'industry': '금융업', 'name': '한진중공업홀딩'},
#  {'code': '000075.KS', 'industry': '금융업', 'name': '삼양홀딩스우'},
#  {'code': '123890.KS', 'industry': '금융업', 'name': '한국자산신탁'},
#  {'code': '003475.KS', 'industry': '금융업', 'name': '유안타증권우'},
#  {'code': '000030.KS', 'industry': '금융업', 'name': '우리은행'},
#  {'code': '071050.KS', 'industry': '금융업', 'name': '한국금융지주'},
#  {'code': '078935.KS', 'industry': '금융업', 'name': 'GS우'},
#  {'code': '138930.KS', 'industry': '금융업', 'name': 'BNK금융지주'},
#  {'code': '003465.KS', 'industry': '금융업', 'name': '유화증권우'},
#  {'code': '03473K.KS', 'industry': '금융업', 'name': 'SK우'},
#  {'code': '001750.KS', 'industry': '금융업', 'name': '한양증권'},
#  {'code': '105560.KS', 'industry': '금융업', 'name': 'KB금융'},
#  {'code': '192530.KS', 'industry': '금융업', 'name': '광주은행'},
#  {'code': '006120.KS', 'industry': '금융업', 'name': 'SK디스커버리'},
#  {'code': '055550.KS', 'industry': '금융업', 'name': '신한지주'},
#  {'code': '071055.KS', 'industry': '금융업', 'name': '한국금융지주우'},
#  {'code': '001045.KS', 'industry': '금융업', 'name': 'CJ우'},
#  {'code': '016450.KS', 'industry': '금융업', 'name': '한세예스24홀'},
#  {'code': '101060.KS', 'industry': '금융업', 'name': 'SBS미디어홀'},
#  {'code': '085620.KS', 'industry': '금융업', 'name': '미래에셋생명'},
#  {'code': '241560.KS', 'industry': '금융업', 'name': '두산밥캣'},
#  {'code': '001040.KS', 'industry': '금융업', 'name': 'CJ'},
#  {'code': '003545.KS', 'industry': '금융업', 'name': '대신증권우'},
#  {'code': '096760.KS', 'industry': '금융업', 'name': 'JW홀딩스'},
#  {'code': '072710.KS', 'industry': '금융업', 'name': '농심홀딩스'},
#  {'code': '000400.KS', 'industry': '금융업', 'name': '롯데손해보험'},
#  {'code': '192400.KS', 'industry': '금융업', 'name': '쿠쿠홀딩스'},
#  {'code': '001515.KS', 'industry': '금융업', 'name': 'SK증권우'},
#  {'code': '033660.KS', 'industry': '금융업', 'name': '아주캐피탈'},
#  {'code': '029780.KS', 'industry': '금융업', 'name': '삼성카드'},
#  {'code': '015360.KS', 'industry': '금융업', 'name': '예스코홀딩스'},
#  {'code': '229640.KS', 'industry': '금융업', 'name': 'LS전선아시아'},
#  {'code': '005945.KS', 'industry': '금융업', 'name': 'NH투자증권우'},
#  {'code': '004150.KS', 'industry': '금융업', 'name': '한솔홀딩스'},
#  {'code': '002020.KS', 'industry': '금융업', 'name': '코오롱'},
#  {'code': '000140.KS', 'industry': '금융업', 'name': '하이트진로홀딩'},
#  {'code': '036530.KS', 'industry': '금융업', 'name': 'S&T홀딩스'},
#  {'code': '100250.KS', 'industry': '금융업', 'name': '진양홀딩스'},
#  {'code': '005940.KS', 'industry': '금융업', 'name': 'NH투자증권'},
#  {'code': '000540.KS', 'industry': '금융업', 'name': '흥국화재'},
#  {'code': '088980.KS', 'industry': '금융업', 'name': '맥쿼리인프라'},
#  {'code': '002790.KS', 'industry': '금융업', 'name': '아모레G'},
#  {'code': '007860.KS', 'industry': '금융업', 'name': '서연'},
#  {'code': '039490.KS', 'industry': '금융업', 'name': '키움증권'},
#  {'code': '016360.KS', 'industry': '금융업', 'name': '삼성증권'},
#  {'code': '006125.KS', 'industry': '금융업', 'name': 'SK디스커버리'},
#  {'code': '004840.KS', 'industry': '금융업', 'name': 'DRB동일'},
#  {'code': '003550.KS', 'industry': '금융업', 'name': 'LG'},
#  {'code': '000815.KS', 'industry': '금융업', 'name': '삼성화재우'},
#  {'code': '003555.KS', 'industry': '금융업', 'name': 'LG우'},
#  {'code': '009440.KS', 'industry': '금융업', 'name': 'KC그린홀딩스'},
#  {'code': '002795.KS', 'industry': '금융업', 'name': '아모레G우'},
#  {'code': '006220.KS', 'industry': '금융업', 'name': '제주은행'},
#  {'code': '013570.KS', 'industry': '금융업', 'name': '디와이'},
#  {'code': '000145.KS', 'industry': '금융업', 'name': '하이트진로홀딩'},
#  {'code': '025530.KS', 'industry': '금융업', 'name': 'SJM홀딩스'},
#  {'code': '001725.KS', 'industry': '금융업', 'name': '신영증권우'},
#  {'code': '003540.KS', 'industry': '금융업', 'name': '대신증권'},
#  {'code': '000070.KS', 'industry': '금융업', 'name': '삼양홀딩스'},
#  {'code': '084695.KS', 'industry': '금융업', 'name': '대상홀딩스우'},
#  {'code': '139130.KS', 'industry': '금융업', 'name': 'DGB금융지주'},
#  {'code': '175330.KS', 'industry': '금융업', 'name': 'JB금융지주'},
#  {'code': '000240.KS', 'industry': '금융업', 'name': '한국타이어월드'},
#  {'code': '001275.KS', 'industry': '금융업', 'name': '부국증권우'},
#  {'code': '000320.KS', 'industry': '금융업', 'name': '노루홀딩스'},
#  {'code': '005720.KS', 'industry': '금융업', 'name': '넥센'},
#  {'code': '016610.KS', 'industry': '금융업', 'name': 'DB금융투자'},
#  {'code': '092230.KS', 'industry': '금융업', 'name': 'KPX홀딩스'},
#  {'code': '017810.KS', 'industry': '금융업', 'name': '풀무원'},
#  {'code': '003547.KS', 'industry': '금융업', 'name': '대신증권2우B'},
#  {'code': '00680K.KS', 'industry': '금융업', 'name': '미래에셋대우2'},
#  {'code': '001720.KS', 'industry': '금융업', 'name': '신영증권'},
#  {'code': '001270.KS', 'industry': '금융업', 'name': '부국증권'},
#  {'code': '060980.KS', 'industry': '금융업', 'name': '한라홀딩스'},
#  {'code': '030610.KS', 'industry': '금융업', 'name': '교보증권'},
#  {'code': '000547.KS', 'industry': '금융업', 'name': '흥국화재2우B'},
#  {'code': '006805.KS', 'industry': '금융업', 'name': '미래에셋대우우'},
#  {'code': '001290.KS', 'industry': '금융업', 'name': '골든브릿지증권'},
#  {'code': '001755.KS', 'industry': '금융업', 'name': '한양증권우'},
#  {'code': '084690.KS', 'industry': '금융업', 'name': '대상홀딩스'},
#  {'code': '010050.KS', 'industry': '금융업', 'name': '우리종금'},
#  {'code': '003530.KS', 'industry': '금융업', 'name': '한화투자증권'},
#  {'code': '18064K.KS', 'industry': '금융업', 'name': '한진칼우'},
#  {'code': '003535.KS', 'industry': '금융업', 'name': '한화투자증권우'},
#  {'code': '082640.KS', 'industry': '금융업', 'name': '동양생명'},
#  {'code': '001510.KS', 'industry': '금융업', 'name': 'SK증권'},
#  {'code': '005810.KS', 'industry': '금융업', 'name': '풍산홀딩스'},
#  {'code': '107590.KS', 'industry': '금융업', 'name': '미원홀딩스'},
#  {'code': '024720.KS', 'industry': '금융업', 'name': '한국콜마홀딩스'},
#  {'code': '003090.KS', 'industry': '금융업', 'name': '대웅'},
#  {'code': '006200.KS', 'industry': '금융업', 'name': '한국전자홀딩스'},
#  {'code': '241590.KS', 'industry': '금융업', 'name': '화승엔터프라이'},
#  {'code': '002025.KS', 'industry': '금융업', 'name': '코오롱우'},
#  {'code': '000590.KS', 'industry': '금융업', 'name': 'CS홀딩스'},
#  {'code': '138040.KS', 'industry': '금융업', 'name': '메리츠금융지주'},
#  {'code': '001500.KS', 'industry': '금융업', 'name': '현대차증권'},
#  {'code': '000640.KS', 'industry': '금융업', 'name': '동아쏘시오홀딩'},
#  {'code': '034830.KS', 'industry': '금융업', 'name': '한국토지신탁'},
#  {'code': '006800.KS', 'industry': '금융업', 'name': '미래에셋대우'},
#  {'code': '012320.KS', 'industry': '금융업', 'name': '경동인베스트'},
#  {'code': '015860.KS', 'industry': '금융업', 'name': '일진홀딩스'},
#  {'code': '000545.KS', 'industry': '금융업', 'name': '흥국화재우'},
#  {'code': '003460.KS', 'industry': '금융업', 'name': '유화증권'},
#  {'code': '008560.KS', 'industry': '금융업', 'name': '메리츠종금증권'},
#  {'code': '000060.KS', 'industry': '금융업', 'name': '메리츠화재'},
#  {'code': '006840.KS', 'industry': '금융업', 'name': 'AK홀딩스'},
#  {'code': '000230.KS', 'industry': '금융업', 'name': '일동홀딩스'},
#  {'code': '005745.KS', 'industry': '금융업', 'name': '크라운해태홀딩'},
#  {'code': '010770.KS', 'industry': '금융업', 'name': '평화홀딩스'},
#  {'code': '079440.KS', 'industry': '금융업', 'name': '오렌지라이프'},
#  {'code': '000325.KS', 'industry': '금융업', 'name': '노루홀딩스우'},
#  {'code': '005725.KS', 'industry': '금융업', 'name': '넥센우'},
#  {'code': '006260.KS', 'industry': '금융업', 'name': 'LS'},
#  {'code': '005740.KS', 'industry': '금융업', 'name': '크라운해태홀딩'},
#  {'code': '030210.KS', 'industry': '금융업', 'name': 'KTB투자증권'},
#  {'code': '071320.KS', 'industry': '전기가스업', 'name': '지역난방공사'},
#  {'code': '015760.KS', 'industry': '전기가스업', 'name': '한국전력'},
#  {'code': '017390.KS', 'industry': '전기가스업', 'name': '서울가스'},
#  {'code': '034590.KS', 'industry': '전기가스업', 'name': '인천도시가스'},
#  {'code': '015350.KS', 'industry': '전기가스업', 'name': '부산가스'},
#  {'code': '267290.KS', 'industry': '전기가스업', 'name': '경동도시가스'},
#  {'code': '004690.KS', 'industry': '전기가스업', 'name': '삼천리'},
#  {'code': '117580.KS', 'industry': '전기가스업', 'name': '대성에너지'},
#  {'code': '036460.KS', 'industry': '전기가스업', 'name': '한국가스공사'},
#  {'code': '272450.KS', 'industry': '운수창고업', 'name': '진에어'},
#  {'code': '089590.KS', 'industry': '운수창고업', 'name': '제주항공'},
#  {'code': '020560.KS', 'industry': '운수창고업', 'name': '아시아나항공'},
#  {'code': '009180.KS', 'industry': '운수창고업', 'name': '한솔로지스틱스'},
#  {'code': '000120.KS', 'industry': '운수창고업', 'name': 'CJ대한통운'},
#  {'code': '005880.KS', 'industry': '운수창고업', 'name': '대한해운'},
#  {'code': '004360.KS', 'industry': '운수창고업', 'name': '세방'},
#  {'code': '004365.KS', 'industry': '운수창고업', 'name': '세방우'},
#  {'code': '084670.KS', 'industry': '운수창고업', 'name': '동양고속'},
#  {'code': '011200.KS', 'industry': '운수창고업', 'name': '현대상선'},
#  {'code': '009070.KS', 'industry': '운수창고업', 'name': 'KCTC'},
#  {'code': '002320.KS', 'industry': '운수창고업', 'name': '한진'},
#  {'code': '014130.KS', 'industry': '운수창고업', 'name': '한익스프레스'},
#  {'code': '086280.KS', 'industry': '운수창고업', 'name': '현대글로비스'},
#  {'code': '003490.KS', 'industry': '운수창고업', 'name': '대한항공'},
#  {'code': '129260.KS', 'industry': '운수창고업', 'name': '인터지스'},
#  {'code': '005430.KS', 'industry': '운수창고업', 'name': '한국공항'},
#  {'code': '028670.KS', 'industry': '운수창고업', 'name': '팬오션'},
#  {'code': '044450.KS', 'industry': '운수창고업', 'name': 'KSS해운'},
#  {'code': '003280.KS', 'industry': '운수창고업', 'name': '흥아해운'},
#  {'code': '003495.KS', 'industry': '운수창고업', 'name': '대한항공우'},
#  {'code': '091810.KS', 'industry': '운수창고업', 'name': '티웨이항공'},
#  {'code': '000650.KS', 'industry': '운수창고업', 'name': '천일고속'},
#  {'code': '004140.KS', 'industry': '운수창고업', 'name': '동방'},
#  {'code': '001140.KS', 'industry': '운수창고업', 'name': '국보'},
#  {'code': '145720.KS', 'industry': '의료정밀', 'name': '덴티움'},
#  {'code': '105840.KS', 'industry': '의료정밀', 'name': '우진'},
#  {'code': '025560.KS', 'industry': '의료정밀', 'name': '미래산업'},
#  {'code': '029460.KS', 'industry': '의료정밀', 'name': '케이씨'},
#  {'code': '003160.KS', 'industry': '의료정밀', 'name': '디아이'},
#  {'code': '281820.KS', 'industry': '의료정밀', 'name': '케이씨텍'},
#  {'code': '020000.KS', 'industry': '섬유의복', 'name': '한섬'},
#  {'code': '084870.KS', 'industry': '섬유의복', 'name': 'TBH글로벌'},
#  {'code': '093050.KS', 'industry': '섬유의복', 'name': 'LF'},
#  {'code': '016090.KS', 'industry': '섬유의복', 'name': '대현'},
#  {'code': '003610.KS', 'industry': '섬유의복', 'name': '방림'},
#  {'code': '005820.KS', 'industry': '섬유의복', 'name': '원림'},
#  {'code': '105630.KS', 'industry': '섬유의복', 'name': '한세실업'},
#  {'code': '007700.KS', 'industry': '섬유의복', 'name': 'F&F'},
#  {'code': '003200.KS', 'industry': '섬유의복', 'name': '일신방직'},
#  {'code': '000950.KS', 'industry': '섬유의복', 'name': '전방'},
#  {'code': '111110.KS', 'industry': '섬유의복', 'name': '호전실업'},
#  {'code': '001460.KS', 'industry': '섬유의복', 'name': 'BYC'},
#  {'code': '005800.KS', 'industry': '섬유의복', 'name': '신영와코루'},
#  {'code': '008500.KS', 'industry': '섬유의복', 'name': '일정실업'},
#  {'code': '000050.KS', 'industry': '섬유의복', 'name': '경방'},
#  {'code': '001070.KS', 'industry': '섬유의복', 'name': '대한방직'},
#  {'code': '001465.KS', 'industry': '섬유의복', 'name': 'BYC우'},
#  {'code': '011300.KS', 'industry': '섬유의복', 'name': '성안'},
#  {'code': '002070.KS', 'industry': '섬유의복', 'name': '남영비비안'},
#  {'code': '001530.KS', 'industry': '섬유의복', 'name': '동일방직'},
#  {'code': '102280.KS', 'industry': '섬유의복', 'name': '쌍방울'},
#  {'code': '009270.KS', 'industry': '섬유의복', 'name': '신원'},
#  {'code': '014990.KS', 'industry': '섬유의복', 'name': '인디에프'},
#  {'code': '093240.KS', 'industry': '섬유의복', 'name': '형지엘리트'},
#  {'code': '007980.KS', 'industry': '섬유의복', 'name': '태평양물산'},
#  {'code': '090370.KS', 'industry': '섬유의복', 'name': '메타랩스'},
#  {'code': '009275.KS', 'industry': '섬유의복', 'name': '신원우'},
#  {'code': '001340.KS', 'industry': '화학', 'name': '백광산업'},
#  {'code': '003350.KS', 'industry': '화학', 'name': '한국화장품제조'},
#  {'code': '005420.KS', 'industry': '화학', 'name': '코스모화학'},
#  {'code': '192820.KS', 'industry': '화학', 'name': '코스맥스'},
#  {'code': '115390.KS', 'industry': '화학', 'name': '락앤락'},
#  {'code': '069260.KS', 'industry': '화학', 'name': '휴켐스'},
#  {'code': '018250.KS', 'industry': '화학', 'name': '애경산업'},
#  {'code': '005070.KS', 'industry': '화학', 'name': '코스모신소재'},
#  {'code': '003240.KS', 'industry': '화학', 'name': '태광산업'},
#  {'code': '010060.KS', 'industry': '화학', 'name': 'OCI'},
#  {'code': '002350.KS', 'industry': '화학', 'name': '넥센타이어'},
#  {'code': '012610.KS', 'industry': '화학', 'name': '경인양행'},
#  {'code': '004250.KS', 'industry': '화학', 'name': 'NPC'},
#  {'code': '090430.KS', 'industry': '화학', 'name': '아모레퍼시픽'},
#  {'code': '161890.KS', 'industry': '화학', 'name': '한국콜마'},
#  {'code': '002840.KS', 'industry': '화학', 'name': '미원상사'},
#  {'code': '010955.KS', 'industry': '화학', 'name': 'S-Oil우'},
#  {'code': '025000.KS', 'industry': '화학', 'name': 'KPX케미칼'},
#  {'code': '006650.KS', 'industry': '화학', 'name': '대한유화'},
#  {'code': '014825.KS', 'industry': '화학', 'name': '동원시스템즈우'},
#  {'code': '051915.KS', 'industry': '화학', 'name': 'LG화학우'},
#  {'code': '298000.KS', 'industry': '화학', 'name': '효성화학'},
#  {'code': '161000.KS', 'industry': '화학', 'name': '애경유화'},
#  {'code': '073240.KS', 'industry': '화학', 'name': '금호타이어'},
#  {'code': '090350.KS', 'industry': '화학', 'name': '노루페인트'},
#  {'code': '025620.KS', 'industry': '화학', 'name': '제이준코스메틱'},
#  {'code': '004000.KS', 'industry': '화학', 'name': '롯데정밀화학'},
#  {'code': '002380.KS', 'industry': '화학', 'name': 'KCC'},
#  {'code': '010950.KS', 'industry': '화학', 'name': 'S-Oil'},
#  {'code': '090435.KS', 'industry': '화학', 'name': '아모레퍼시픽우'},
#  {'code': '011785.KS', 'industry': '화학', 'name': '금호석유우'},
#  {'code': '078520.KS', 'industry': '화학', 'name': '에이블씨엔씨'},
#  {'code': '226320.KS', 'industry': '화학', 'name': '잇츠한불'},
#  {'code': '001570.KS', 'industry': '화학', 'name': '금양'},
#  {'code': '007690.KS', 'industry': '화학', 'name': '국도화학'},
#  {'code': '004800.KS', 'industry': '화학', 'name': '효성'},
#  {'code': '009830.KS', 'industry': '화학', 'name': '한화케미칼'},
#  {'code': '144620.KS', 'industry': '화학', 'name': '코오롱머티리얼'},
#  {'code': '138490.KS', 'industry': '화학', 'name': '코오롱플라스틱'},
#  {'code': '282690.KS', 'industry': '화학', 'name': '동아타이어'},
#  {'code': '011170.KS', 'industry': '화학', 'name': '롯데케미칼'},
#  {'code': '089470.KS', 'industry': '화학', 'name': 'HDC현대EP'},
#  {'code': '008490.KS', 'industry': '화학', 'name': '서흥'},
#  {'code': '003080.KS', 'industry': '화학', 'name': '성보화학'},
#  {'code': '006380.KS', 'industry': '화학', 'name': '카프로'},
#  {'code': '268280.KS', 'industry': '화학', 'name': '미원에스씨'},
#  {'code': '011780.KS', 'industry': '화학', 'name': '금호석유'},
#  {'code': '023450.KS', 'industry': '화학', 'name': '동남합성'},
#  {'code': '002960.KS', 'industry': '화학', 'name': '한국쉘석유'},
#  {'code': '006060.KS', 'industry': '화학', 'name': '화승인더'},
#  {'code': '006890.KS', 'industry': '화학', 'name': '태경화학'},
#  {'code': '015890.KS', 'industry': '화학', 'name': '태경산업'},
#  {'code': '010640.KS', 'industry': '화학', 'name': '진양폴리'},
#  {'code': '079980.KS', 'industry': '화학', 'name': '휴비스'},
#  {'code': '000860.KS', 'industry': '화학', 'name': '강남제비스코'},
#  {'code': '024890.KS', 'industry': '화학', 'name': '대원화성'},
#  {'code': '005950.KS', 'industry': '화학', 'name': '이수화학'},
#  {'code': '003830.KS', 'industry': '화학', 'name': '대한화섬'},
#  {'code': '051905.KS', 'industry': '화학', 'name': 'LG생활건강우'},
#  {'code': '002355.KS', 'industry': '화학', 'name': '넥센타이어1우'},
#  {'code': '002355.KS', 'industry': '화학', 'name': '넥센타이어1우'},
#  {'code': '008730.KS', 'industry': '화학', 'name': '율촌화학'},
#  {'code': '014820.KS', 'industry': '화학', 'name': '동원시스템즈'},
#  {'code': '120110.KS', 'industry': '화학', 'name': '코오롱인더'},
#  {'code': '002360.KS', 'industry': '화학', 'name': 'SH에너지화학'},
#  {'code': '009835.KS', 'industry': '화학', 'name': '한화케미칼우'},
#  {'code': '014830.KS', 'industry': '화학', 'name': '유니드'},
#  {'code': '011790.KS', 'industry': '화학', 'name': 'SKC'},
#  {'code': '014440.KS', 'industry': '화학', 'name': '영보화학'},
#  {'code': '003650.KS', 'industry': '화학', 'name': '미창석유'},
#  {'code': '108675.KS', 'industry': '화학', 'name': 'LG하우시스우'},
#  {'code': '051900.KS', 'industry': '화학', 'name': 'LG생활건강'},
#  {'code': '120115.KS', 'industry': '화학', 'name': '코오롱인더우'},
#  {'code': '024070.KS', 'industry': '화학', 'name': 'WISCOM'},
#  {'code': '014680.KS', 'industry': '화학', 'name': '한솔케미칼'},
#  {'code': '161390.KS', 'industry': '화학', 'name': '한국타이어'},
#  {'code': '001390.KS', 'industry': '화학', 'name': 'KG케미칼'},
#  {'code': '163560.KS', 'industry': '화학', 'name': '동일고무벨트'},
#  {'code': '108670.KS', 'industry': '화학', 'name': 'LG하우시스'},
#  {'code': '093370.KS', 'industry': '화학', 'name': '후성'},
#  {'code': '28513K.KS', 'industry': '화학', 'name': 'SK케미칼우'},
#  {'code': '272550.KS', 'industry': '화학', 'name': '삼양패키징'},
#  {'code': '134380.KS', 'industry': '화학', 'name': '미원화학'},
#  {'code': '083420.KS', 'industry': '화학', 'name': '그린케미칼'},
#  {'code': '014530.KS', 'industry': '화학', 'name': '극동유화'},
#  {'code': '051630.KS', 'industry': '화학', 'name': '진양화학'},
#  {'code': '00088K.KS', 'industry': '화학', 'name': '한화3우B'},
#  {'code': '003720.KS', 'industry': '화학', 'name': '삼영화학'},
#  {'code': '298020.KS', 'industry': '화학', 'name': '효성티앤씨'},
#  {'code': '011500.KS', 'industry': '화학', 'name': '한농화성'},
#  {'code': '090355.KS', 'industry': '화학', 'name': '노루페인트우'},
#  {'code': '025860.KS', 'industry': '화학', 'name': '남해화학'},
#  {'code': '051910.KS', 'industry': '화학', 'name': 'LG화학'},
#  {'code': '000880.KS', 'industry': '화학', 'name': '한화'},
#  {'code': '298050.KS', 'industry': '화학', 'name': '효성첨단소재'},
#  {'code': '000390.KS', 'industry': '화학', 'name': '삼화페인트'},
#  {'code': '004430.KS', 'industry': '화학', 'name': '송원산업'},
#  {'code': '007590.KS', 'industry': '화학', 'name': '동방아그로'},
#  {'code': '035150.KS', 'industry': '화학', 'name': '백산'},
#  {'code': '004910.KS', 'industry': '화학', 'name': '조광페인트'},
#  {'code': '003780.KS', 'industry': '화학', 'name': '진양산업'},
#  {'code': '004830.KS', 'industry': '화학', 'name': '덕성'},
#  {'code': '000885.KS', 'industry': '화학', 'name': '한화우'},
#  {'code': '002100.KS', 'industry': '화학', 'name': '경농'},
#  {'code': '004255.KS', 'industry': '화학', 'name': 'NPC우'},
#  {'code': '055490.KS', 'industry': '화학', 'name': '테이팩스'},
#  {'code': '214420.KS', 'industry': '화학', 'name': '토니모리'},
#  {'code': '005190.KS', 'industry': '화학', 'name': '동성화학'},
#  {'code': '002760.KS', 'industry': '화학', 'name': '보락'},
#  {'code': '001550.KS', 'industry': '화학', 'name': '조비'},
#  {'code': '081000.KS', 'industry': '화학', 'name': '일진다이아'},
#  {'code': '004835.KS', 'industry': '화학', 'name': '덕성우'},
#  {'code': '028050.KS', 'industry': '서비스업', 'name': '삼성엔지니어링'},
#  {'code': '012030.KS', 'industry': '서비스업', 'name': 'DB'},
#  {'code': '058850.KS', 'industry': '서비스업', 'name': 'KTcs'},
#  {'code': '030000.KS', 'industry': '서비스업', 'name': '제일기획'},
#  {'code': '286940.KS', 'industry': '서비스업', 'name': '롯데정보통신'},
#  {'code': '145270.KS', 'industry': '서비스업', 'name': '케이탑리츠'},
#  {'code': '037560.KS', 'industry': '서비스업', 'name': 'CJ헬로'},
#  {'code': '058860.KS', 'industry': '서비스업', 'name': '케이티스'},
#  {'code': '007120.KS', 'industry': '서비스업', 'name': '미래아이앤지'},
#  {'code': '130660.KS', 'industry': '서비스업', 'name': '한전산업'},
#  {'code': '126560.KS', 'industry': '서비스업', 'name': '현대에이치씨엔'},
#  {'code': '012750.KS', 'industry': '서비스업', 'name': '에스원'},
#  {'code': '023590.KS', 'industry': '서비스업', 'name': '다우기술'},
#  {'code': '035510.KS', 'industry': '서비스업', 'name': '신세계 I&C'},
#  {'code': '011420.KS', 'industry': '서비스업', 'name': '갤럭시아에스엠'},
#  {'code': '094280.KS', 'industry': '서비스업', 'name': '효성ITX'},
#  {'code': '035250.KS', 'industry': '서비스업', 'name': '강원랜드'},
#  {'code': '181710.KS', 'industry': '서비스업', 'name': 'NHN엔터테인'},
#  {'code': '053210.KS', 'industry': '서비스업', 'name': '스카이라이프'},
#  {'code': '068290.KS', 'industry': '서비스업', 'name': '삼성출판사'},
#  {'code': '036570.KS', 'industry': '서비스업', 'name': '엔씨소프트'},
#  {'code': '102260.KS', 'industry': '서비스업', 'name': '동성코퍼레이션'},
#  {'code': '293940.KS', 'industry': '서비스업', 'name': '신한알파리츠'},
#  {'code': '005257.KS', 'industry': '서비스업', 'name': '녹십자홀딩스2'},
#  {'code': '078000.KS', 'industry': '서비스업', 'name': '텔코웨어'},
#  {'code': '021240.KS', 'industry': '서비스업', 'name': '코웨이'},
#  {'code': '012510.KS', 'industry': '서비스업', 'name': '더존비즈온'},
#  {'code': '002420.KS', 'industry': '서비스업', 'name': '세기상사'},
#  {'code': '018260.KS', 'industry': '서비스업', 'name': '삼성에스디에스'},
#  {'code': '095720.KS', 'industry': '서비스업', 'name': '웅진씽크빅'},
#  {'code': '035420.KS', 'industry': '서비스업', 'name': 'NAVER'},
#  {'code': '016710.KS', 'industry': '서비스업', 'name': '대성홀딩스'},
#  {'code': '140910.KS', 'industry': '서비스업', 'name': '에이리츠'},
#  {'code': '003560.KS', 'industry': '서비스업', 'name': 'IHQ'},
#  {'code': '000157.KS', 'industry': '서비스업', 'name': '두산2우B'},
#  {'code': '000155.KS', 'industry': '서비스업', 'name': '두산우'},
#  {'code': '204210.KS', 'industry': '서비스업', 'name': '모두투어리츠'},
#  {'code': '019680.KS', 'industry': '서비스업', 'name': '대교'},
#  {'code': '015020.KS', 'industry': '서비스업', 'name': '이스타코'},
#  {'code': '140890.KS', 'industry': '서비스업', 'name': '트러스제7호'},
#  {'code': '035000.KS', 'industry': '서비스업', 'name': '지투알'},
#  {'code': '083370.KS', 'industry': '서비스업', 'name': '동북아12호'},
#  {'code': '083380.KS', 'industry': '서비스업', 'name': '동북아13호'},
#  {'code': '172580.KS', 'industry': '서비스업', 'name': '하이골드12호'},
#  {'code': '039130.KS', 'industry': '서비스업', 'name': '하나투어'},
#  {'code': '210980.KS', 'industry': '서비스업', 'name': 'SK디앤디'},
#  {'code': '214320.KS', 'industry': '서비스업', 'name': '이노션'},
#  {'code': '088260.KS', 'industry': '서비스업', 'name': '이리츠코크렙'},
#  {'code': '114090.KS', 'industry': '서비스업', 'name': 'GKL'},
#  {'code': '034120.KS', 'industry': '서비스업', 'name': 'SBS'},
#  {'code': '100220.KS', 'industry': '서비스업', 'name': '비상교육'},
#  {'code': '153360.KS', 'industry': '서비스업', 'name': '하이골드3호'},
#  {'code': '019685.KS', 'industry': '서비스업', 'name': '대교우B'},
#  {'code': '032350.KS', 'industry': '서비스업', 'name': '롯데관광개발'},
#  {'code': '002030.KS', 'industry': '서비스업', 'name': '아세아'},
#  {'code': '031440.KS', 'industry': '서비스업', 'name': '신세계푸드'},
#  {'code': '155900.KS', 'industry': '서비스업', 'name': '바다로19호'},
#  {'code': '052690.KS', 'industry': '서비스업', 'name': '한전기술'},
#  {'code': '000700.KS', 'industry': '서비스업', 'name': '유수홀딩스'},
#  {'code': '159650.KS', 'industry': '서비스업', 'name': '하이골드8호'},
#  {'code': '284740.KS', 'industry': '서비스업', 'name': '쿠쿠홈시스'},
#  {'code': '079160.KS', 'industry': '서비스업', 'name': 'CJ CGV'},
#  {'code': '072130.KS', 'industry': '서비스업', 'name': '유엔젤'},
#  {'code': '000150.KS', 'industry': '서비스업', 'name': '두산'},
#  {'code': '035720.KS', 'industry': '서비스업', 'name': '카카오'},
#  {'code': '053690.KS', 'industry': '서비스업', 'name': '한미글로벌'},
#  {'code': '000180.KS', 'industry': '서비스업', 'name': '성창기업지주'},
#  {'code': '005250.KS', 'industry': '서비스업', 'name': '녹십자홀딩스'},
#  {'code': '034310.KS', 'industry': '서비스업', 'name': 'NICE'},
#  {'code': '070960.KS', 'industry': '서비스업', 'name': '용평리조트'},
#  {'code': '084680.KS', 'industry': '서비스업', 'name': '이월드'},
#  {'code': '020120.KS', 'industry': '서비스업', 'name': '키다리스튜디오'},
#  {'code': '015540.KS', 'industry': '서비스업', 'name': '메디플란트'},
#  {'code': '002620.KS', 'industry': '서비스업', 'name': '제일파마홀딩스'},
#  {'code': '003300.KS', 'industry': '서비스업', 'name': '한일홀딩스'},
#  {'code': '251270.KS', 'industry': '서비스업', 'name': '넷마블'},
#  {'code': '095570.KS', 'industry': '서비스업', 'name': 'AJ네트웍스'},
#  {'code': '023350.KS', 'industry': '서비스업', 'name': '한국종합기술'},
#  {'code': '002150.KS', 'industry': '서비스업', 'name': '도화엔지니어링'},
#  {'code': '068400.KS', 'industry': '서비스업', 'name': 'AJ렌터카'},
#  {'code': '030790.KS', 'industry': '서비스업', 'name': '동양네트웍스'},
#  {'code': '031820.KS', 'industry': '서비스업', 'name': '콤텍시스템'},
#  {'code': '248170.KS', 'industry': '음식료품', 'name': '샘표식품'},
#  {'code': '003230.KS', 'industry': '음식료품', 'name': '삼양식품'},
#  {'code': '079660.KS', 'industry': '음식료품', 'name': '사조해표'},
#  {'code': '033920.KS', 'industry': '음식료품', 'name': '무학'},
#  {'code': '003960.KS', 'industry': '음식료품', 'name': '사조대림'},
#  {'code': '036580.KS', 'industry': '음식료품', 'name': '팜스코'},
#  {'code': '001680.KS', 'industry': '음식료품', 'name': '대상'},
#  {'code': '000890.KS', 'industry': '음식료품', 'name': '보해양조'},
#  {'code': '003680.KS', 'industry': '음식료품', 'name': '한성기업'},
#  {'code': '001130.KS', 'industry': '음식료품', 'name': '대한제분'},
#  {'code': '145990.KS', 'industry': '음식료품', 'name': '삼양사'},
#  {'code': '007310.KS', 'industry': '음식료품', 'name': '오뚜기'},
#  {'code': '097950.KS', 'industry': '음식료품', 'name': 'CJ제일제당'},
#  {'code': '000080.KS', 'industry': '음식료품', 'name': '하이트진로'},
#  {'code': '002140.KS', 'industry': '음식료품', 'name': '고려산업'},
#  {'code': '003920.KS', 'industry': '음식료품', 'name': '남양유업'},
#  {'code': '011155.KS', 'industry': '음식료품', 'name': 'CJ씨푸드1우'},
#  {'code': '049770.KS', 'industry': '음식료품', 'name': '동원F&B'},
#  {'code': '101530.KS', 'industry': '음식료품', 'name': '해태제과식품'},
#  {'code': '097955.KS', 'industry': '음식료품', 'name': 'CJ제일제당 '},
#  {'code': '001685.KS', 'industry': '음식료품', 'name': '대상우'},
#  {'code': '000087.KS', 'industry': '음식료품', 'name': '하이트진로2우'},
#  {'code': '014710.KS', 'industry': '음식료품', 'name': '사조씨푸드'},
#  {'code': '004415.KS', 'industry': '음식료품', 'name': '서울식품우'},
#  {'code': '005300.KS', 'industry': '음식료품', 'name': '롯데칠성'},
#  {'code': '004370.KS', 'industry': '음식료품', 'name': '농심'},
#  {'code': '005305.KS', 'industry': '음식료품', 'name': '롯데칠성우'},
#  {'code': '003925.KS', 'industry': '음식료품', 'name': '남양유업우'},
#  {'code': '023150.KS', 'industry': '음식료품', 'name': 'MH에탄올'},
#  {'code': '027740.KS', 'industry': '음식료품', 'name': '마니커'},
#  {'code': '005180.KS', 'industry': '음식료품', 'name': '빙그레'},
#  {'code': '001790.KS', 'industry': '음식료품', 'name': '대한제당'},
#  {'code': '006090.KS', 'industry': '음식료품', 'name': '사조오양'},
#  {'code': '006980.KS', 'industry': '음식료품', 'name': '우성사료'},
#  {'code': '002600.KS', 'industry': '음식료품', 'name': '조흥'},
#  {'code': '011150.KS', 'industry': '음식료품', 'name': 'CJ씨푸드'},
#  {'code': '26490K.KS', 'industry': '음식료품', 'name': '크라운제과우'},
#  {'code': '136490.KS', 'industry': '음식료품', 'name': '선진'},
#  {'code': '264900.KS', 'industry': '음식료품', 'name': '크라운제과'},
#  {'code': '008040.KS', 'industry': '음식료품', 'name': '사조동아원'},
#  {'code': '005610.KS', 'industry': '음식료품', 'name': 'SPC삼립'},
#  {'code': '001795.KS', 'industry': '음식료품', 'name': '대한제당우'},
#  {'code': '280360.KS', 'industry': '음식료품', 'name': '롯데제과'},
#  {'code': '004410.KS', 'industry': '음식료품', 'name': '서울식품'},
#  {'code': '002270.KS', 'industry': '음식료품', 'name': '롯데푸드'},
#  {'code': '145995.KS', 'industry': '음식료품', 'name': '삼양사우'},
#  {'code': '271560.KS', 'industry': '음식료품', 'name': '오리온'},
#  {'code': '001799.KS', 'industry': '음식료품', 'name': '대한제당3우B'},
#  {'code': '005500.KS', 'industry': '중형주', 'name': '삼진제약'},
#  {'code': '030000.KS', 'industry': '중형주', 'name': '제일기획'},
#  {'code': '005420.KS', 'industry': '중형주', 'name': '코스모화학'},
#  {'code': '192820.KS', 'industry': '중형주', 'name': '코스맥스'},
#  {'code': '003850.KS', 'industry': '중형주', 'name': '보령제약'},
#  {'code': '115390.KS', 'industry': '중형주', 'name': '락앤락'},
#  {'code': '003230.KS', 'industry': '중형주', 'name': '삼양식품'},
#  {'code': '069260.KS', 'industry': '중형주', 'name': '휴켐스'},
#  {'code': '020000.KS', 'industry': '중형주', 'name': '한섬'},
#  {'code': '019170.KS', 'industry': '중형주', 'name': '신풍제약'},
#  {'code': '003240.KS', 'industry': '중형주', 'name': '태광산업'},
#  {'code': '003470.KS', 'industry': '중형주', 'name': '유안타증권'},
#  {'code': '058650.KS', 'industry': '중형주', 'name': '세아홀딩스'},
#  {'code': '037560.KS', 'industry': '중형주', 'name': 'CJ헬로'},
#  {'code': '002350.KS', 'industry': '중형주', 'name': '넥센타이어'},
#  {'code': '009450.KS', 'industry': '중형주', 'name': '경동나비엔'},
#  {'code': '005440.KS', 'industry': '중형주', 'name': '현대그린푸드'},
#  {'code': '093050.KS', 'industry': '중형주', 'name': 'LF'},
#  {'code': '009970.KS', 'industry': '중형주', 'name': '영원무역홀딩스'},
#  {'code': '033920.KS', 'industry': '중형주', 'name': '무학'},
#  {'code': '001800.KS', 'industry': '중형주', 'name': '오리온홀딩스'},
#  {'code': '180640.KS', 'industry': '중형주', 'name': '한진칼'},
#  {'code': '006360.KS', 'industry': '중형주', 'name': 'GS건설'},
#  {'code': '000370.KS', 'industry': '중형주', 'name': '한화손해보험'},
#  {'code': '185750.KS', 'industry': '중형주', 'name': '종근당'},
#  {'code': '161890.KS', 'industry': '중형주', 'name': '한국콜마'},
#  {'code': '089590.KS', 'industry': '중형주', 'name': '제주항공'},
#  {'code': '126560.KS', 'industry': '중형주', 'name': '현대에이치씨엔'},
#  {'code': '111770.KS', 'industry': '중형주', 'name': '영원무역'},
#  {'code': '145720.KS', 'industry': '중형주', 'name': '덴티움'},
#  {'code': '020560.KS', 'industry': '중형주', 'name': '아시아나항공'},
#  {'code': '003690.KS', 'industry': '중형주', 'name': '코리안리'},
#  {'code': '071320.KS', 'industry': '중형주', 'name': '지역난방공사'},
#  {'code': '057050.KS', 'industry': '중형주', 'name': '현대홈쇼핑'},
#  {'code': '036580.KS', 'industry': '중형주', 'name': '팜스코'},
#  {'code': '023590.KS', 'industry': '중형주', 'name': '다우기술'},
#  {'code': '006040.KS', 'industry': '중형주', 'name': '동원산업'},
#  {'code': '001680.KS', 'industry': '중형주', 'name': '대상'},
#  {'code': '123890.KS', 'industry': '중형주', 'name': '한국자산신탁'},
#  {'code': '138250.KS', 'industry': '중형주', 'name': '엔에스쇼핑'},
#  {'code': '181710.KS', 'industry': '중형주', 'name': 'NHN엔터테인'},
#  {'code': '006650.KS', 'industry': '중형주', 'name': '대한유화'},
#  {'code': '053210.KS', 'industry': '중형주', 'name': '스카이라이프'},
#  {'code': '042670.KS', 'industry': '중형주', 'name': '두산인프라코어'},
#  {'code': '145990.KS', 'industry': '중형주', 'name': '삼양사'},
#  {'code': '161000.KS', 'industry': '중형주', 'name': '애경유화'},
#  {'code': '005850.KS', 'industry': '중형주', 'name': '에스엘'},
#  {'code': '073240.KS', 'industry': '중형주', 'name': '금호타이어'},
#  {'code': '017390.KS', 'industry': '중형주', 'name': '서울가스'},
#  {'code': '001120.KS', 'industry': '중형주', 'name': 'LG상사'},
#  {'code': '192530.KS', 'industry': '중형주', 'name': '광주은행'},
#  {'code': '006120.KS', 'industry': '중형주', 'name': 'SK디스커버리'},
#  {'code': '000080.KS', 'industry': '중형주', 'name': '하이트진로'},
#  {'code': '005880.KS', 'industry': '중형주', 'name': '대한해운'},
#  {'code': '033270.KS', 'industry': '중형주', 'name': '유나이티드제약'},
#  {'code': '016450.KS', 'industry': '중형주', 'name': '한세예스24홀'},
#  {'code': '025620.KS', 'industry': '중형주', 'name': '제이준코스메틱'},
#  {'code': '101060.KS', 'industry': '중형주', 'name': 'SBS미디어홀'},
#  {'code': '010780.KS', 'industry': '중형주', 'name': '아이에스동서'},
#  {'code': '085620.KS', 'industry': '중형주', 'name': '미래에셋생명'},
#  {'code': '004000.KS', 'industry': '중형주', 'name': '롯데정밀화학'},
#  {'code': '096760.KS', 'industry': '중형주', 'name': 'JW홀딩스'},
#  {'code': '072710.KS', 'industry': '중형주', 'name': '농심홀딩스'},
#  {'code': '000400.KS', 'industry': '중형주', 'name': '롯데손해보험'},
#  {'code': '003000.KS', 'industry': '중형주', 'name': '부광약품'},
#  {'code': '078520.KS', 'industry': '중형주', 'name': '에이블씨엔씨'},
#  {'code': '226320.KS', 'industry': '중형주', 'name': '잇츠한불'},
#  {'code': '105630.KS', 'industry': '중형주', 'name': '한세실업'},
#  {'code': '192400.KS', 'industry': '중형주', 'name': '쿠쿠홀딩스'},
#  {'code': '003920.KS', 'industry': '중형주', 'name': '남양유업'},
#  {'code': '033660.KS', 'industry': '중형주', 'name': '아주캐피탈'},
#  {'code': '027410.KS', 'industry': '중형주', 'name': 'BGF'},
#  {'code': '049770.KS', 'industry': '중형주', 'name': '동원F&B'},
#  {'code': '012510.KS', 'industry': '중형주', 'name': '더존비즈온'},
#  {'code': '010620.KS', 'industry': '중형주', 'name': '현대미포조선'},
#  {'code': '007700.KS', 'industry': '중형주', 'name': 'F&F'},
#  {'code': '170900.KS', 'industry': '중형주', 'name': '동아에스티'},
#  {'code': '101530.KS', 'industry': '중형주', 'name': '해태제과식품'},
#  {'code': '002020.KS', 'industry': '중형주', 'name': '코오롱'},
#  {'code': '001740.KS', 'industry': '중형주', 'name': 'SK네트웍스'},
#  {'code': '039490.KS', 'industry': '중형주', 'name': '키움증권'},
#  {'code': '011200.KS', 'industry': '중형주', 'name': '현대상선'},
#  {'code': '051600.KS', 'industry': '중형주', 'name': '한전KPS'},
#  {'code': '007570.KS', 'industry': '중형주', 'name': '일양약품'},
#  {'code': '015350.KS', 'industry': '중형주', 'name': '부산가스'},
#  {'code': '005300.KS', 'industry': '중형주', 'name': '롯데칠성'},
#  {'code': '004370.KS', 'industry': '중형주', 'name': '농심'},
#  {'code': '002240.KS', 'industry': '중형주', 'name': '고려제강'},
#  {'code': '002960.KS', 'industry': '중형주', 'name': '한국쉘석유'},
#  {'code': '019680.KS', 'industry': '중형주', 'name': '대교'},
#  {'code': '006060.KS', 'industry': '중형주', 'name': '화승인더'},
#  {'code': '029530.KS', 'industry': '중형주', 'name': '신도리코'},
#  {'code': '069960.KS', 'industry': '중형주', 'name': '현대백화점'},
#  {'code': '010120.KS', 'industry': '중형주', 'name': 'LS산전'},
#  {'code': '017810.KS', 'industry': '중형주', 'name': '풀무원'},
#  {'code': '000070.KS', 'industry': '중형주', 'name': '삼양홀딩스'},
#  {'code': '004690.KS', 'industry': '중형주', 'name': '삼천리'},
#  {'code': '175330.KS', 'industry': '중형주', 'name': 'JB금융지주'},
#  {'code': '005180.KS', 'industry': '중형주', 'name': '빙그레'},
#  {'code': '000240.KS', 'industry': '중형주', 'name': '한국타이어월드'},
#  {'code': '007460.KS', 'industry': '중형주', 'name': '에이프로젠 K'},
#  {'code': '183190.KS', 'industry': '중형주', 'name': '아세아시멘트'},
#  {'code': '285130.KS', 'industry': '중형주', 'name': 'SK케미칼'},
#  {'code': '003540.KS', 'industry': '중형주', 'name': '대신증권'},
#  {'code': '120110.KS', 'industry': '중형주', 'name': '코오롱인더'},
#  {'code': '008730.KS', 'industry': '중형주', 'name': '율촌화학'},
#  {'code': '014820.KS', 'industry': '중형주', 'name': '동원시스템즈'},
#  {'code': '005720.KS', 'industry': '중형주', 'name': '넥센'},
#  {'code': '014830.KS', 'industry': '중형주', 'name': '유니드'},
#  {'code': '210980.KS', 'industry': '중형주', 'name': 'SK디앤디'},
#  {'code': '214320.KS', 'industry': '중형주', 'name': '이노션'},
#  {'code': '039130.KS', 'industry': '중형주', 'name': '하나투어'},
#  {'code': '069620.KS', 'industry': '중형주', 'name': '대웅제약'},
#  {'code': '139130.KS', 'industry': '중형주', 'name': 'DGB금융지주'},
#  {'code': '001430.KS', 'industry': '중형주', 'name': '세아베스틸'},
#  {'code': '003030.KS', 'industry': '중형주', 'name': '세아제강'},
#  {'code': '003620.KS', 'industry': '중형주', 'name': '쌍용차'},
#  {'code': '011790.KS', 'industry': '중형주', 'name': 'SKC'},
#  {'code': '004490.KS', 'industry': '중형주', 'name': '세방전지'},
#  {'code': '071840.KS', 'industry': '중형주', 'name': '롯데하이마트'},
#  {'code': '001720.KS', 'industry': '중형주', 'name': '신영증권'},
#  {'code': '114090.KS', 'industry': '중형주', 'name': 'GKL'},
#  {'code': '079430.KS', 'industry': '중형주', 'name': '현대리바트'},
#  {'code': '016580.KS', 'industry': '중형주', 'name': '환인제약'},
#  {'code': '003520.KS', 'industry': '중형주', 'name': '영진약품'},
#  {'code': '034120.KS', 'industry': '중형주', 'name': 'SBS'},
#  {'code': '060980.KS', 'industry': '중형주', 'name': '한라홀딩스'},
#  {'code': '011810.KS', 'industry': '중형주', 'name': 'STX'},
#  {'code': '000990.KS', 'industry': '중형주', 'name': 'DB하이텍'},
#  {'code': '032350.KS', 'industry': '중형주', 'name': '롯데관광개발'},
#  {'code': '034020.KS', 'industry': '중형주', 'name': '두산중공업'},
#  {'code': '014680.KS', 'industry': '중형주', 'name': '한솔케미칼'},
#  {'code': '008060.KS', 'industry': '중형주', 'name': '대덕전자'},
#  {'code': '003530.KS', 'industry': '중형주', 'name': '한화투자증권'},
#  {'code': '009410.KS', 'industry': '중형주', 'name': '태영건설'},
#  {'code': '033240.KS', 'industry': '중형주', 'name': '자화전자'},
#  {'code': '108670.KS', 'industry': '중형주', 'name': 'LG하우시스'},
#  {'code': '031440.KS', 'industry': '중형주', 'name': '신세계푸드'},
#  {'code': '082640.KS', 'industry': '중형주', 'name': '동양생명'},
#  {'code': '093370.KS', 'industry': '중형주', 'name': '후성'},
#  {'code': '011210.KS', 'industry': '중형주', 'name': '현대위아'},
#  {'code': '001510.KS', 'industry': '중형주', 'name': 'SK증권'},
#  {'code': '005810.KS', 'industry': '중형주', 'name': '풍산홀딩스'},
#  {'code': '024720.KS', 'industry': '중형주', 'name': '한국콜마홀딩스'},
#  {'code': '003090.KS', 'industry': '중형주', 'name': '대웅'},
#  {'code': '267260.KS', 'industry': '중형주', 'name': '현대일렉트릭'},
#  {'code': '241590.KS', 'industry': '중형주', 'name': '화승엔터프라이'},
#  {'code': '018670.KS', 'industry': '중형주', 'name': 'SK가스'},
#  {'code': '052690.KS', 'industry': '중형주', 'name': '한전기술'},
#  {'code': '005610.KS', 'industry': '중형주', 'name': 'SPC삼립'},
#  {'code': '001520.KS', 'industry': '중형주', 'name': '동양'},
#  {'code': '000050.KS', 'industry': '중형주', 'name': '경방'},
#  {'code': '000670.KS', 'industry': '중형주', 'name': '영풍'},
#  {'code': '138040.KS', 'industry': '중형주', 'name': '메리츠금융지주'},
#  {'code': '001440.KS', 'industry': '중형주', 'name': '대한전선'},
#  {'code': '004130.KS', 'industry': '중형주', 'name': '대덕GDS'},
#  {'code': '025540.KS', 'industry': '중형주', 'name': '한국단자'},
#  {'code': '280360.KS', 'industry': '중형주', 'name': '롯데제과'},
#  {'code': '042660.KS', 'industry': '중형주', 'name': '대우조선해양'},
#  {'code': '000640.KS', 'industry': '중형주', 'name': '동아쏘시오홀딩'},
#  {'code': '034830.KS', 'industry': '중형주', 'name': '한국토지신탁'},
#  {'code': '284740.KS', 'industry': '중형주', 'name': '쿠쿠홈시스'},
#  {'code': '079160.KS', 'industry': '중형주', 'name': 'CJ CGV'},
#  {'code': '271980.KS', 'industry': '중형주', 'name': '제일약품'},
#  {'code': '003410.KS', 'industry': '중형주', 'name': '쌍용양회'},
#  {'code': '025860.KS', 'industry': '중형주', 'name': '남해화학'},
#  {'code': '000150.KS', 'industry': '중형주', 'name': '두산'},
#  {'code': '001060.KS', 'industry': '중형주', 'name': 'JW중외제약'},
#  {'code': '249420.KS', 'industry': '중형주', 'name': '일동제약'},
#  {'code': '267270.KS', 'industry': '중형주', 'name': '현대건설기계'},
#  {'code': '003220.KS', 'industry': '중형주', 'name': '대원제약'},
#  {'code': '006840.KS', 'industry': '중형주', 'name': 'AK홀딩스'},
#  {'code': '009290.KS', 'industry': '중형주', 'name': '광동제약'},
#  {'code': '081660.KS', 'industry': '중형주', 'name': '휠라코리아'},
#  {'code': '031430.KS', 'industry': '중형주', 'name': '신세계인터내셔'},
#  {'code': '004430.KS', 'industry': '중형주', 'name': '송원산업'},
#  {'code': '112610.KS', 'industry': '중형주', 'name': '씨에스윈드'},
#  {'code': '002270.KS', 'industry': '중형주', 'name': '롯데푸드'},
#  {'code': '281820.KS', 'industry': '중형주', 'name': '케이씨텍'},
#  {'code': '017940.KS', 'industry': '중형주', 'name': 'E1'},
#  {'code': '005250.KS', 'industry': '중형주', 'name': '녹십자홀딩스'},
#  {'code': '034310.KS', 'industry': '중형주', 'name': 'NICE'},
#  {'code': '070960.KS', 'industry': '중형주', 'name': '용평리조트'},
#  {'code': '064960.KS', 'industry': '중형주', 'name': 'S&T모티브'},
#  {'code': '103140.KS', 'industry': '중형주', 'name': '풍산'},
#  {'code': '047040.KS', 'industry': '중형주', 'name': '대우건설'},
#  {'code': '003300.KS', 'industry': '중형주', 'name': '한일홀딩스'},
#  {'code': '001230.KS', 'industry': '중형주', 'name': '동국제강'},
#  {'code': '006260.KS', 'industry': '중형주', 'name': 'LS'},
#  {'code': '020150.KS', 'industry': '중형주', 'name': '일진머티리얼즈'},
#  {'code': '079550.KS', 'industry': '중형주', 'name': 'LIG넥스원'},
#  {'code': '042700.KS', 'industry': '중형주', 'name': '한미반도체'},
#  {'code': '002390.KS', 'industry': '중형주', 'name': '한독'},
#  {'code': '017800.KS', 'industry': '중형주', 'name': '현대엘리베이'},
#  {'code': '064350.KS', 'industry': '중형주', 'name': '현대로템'},
#  {'code': '004380.KS', 'industry': '중형주', 'name': '삼익THK'},
#  {'code': '009420.KS', 'industry': '중형주', 'name': '한올바이오파마'},
#  {'code': '001820.KS', 'industry': '중형주', 'name': '삼화콘덴서'},
#  {'code': '012450.KS', 'industry': '중형주', 'name': '한화에어로스페'},
#  {'code': '009580.KS', 'industry': '종이목재', 'name': '무림P&P'},
#  {'code': '009770.KS', 'industry': '종이목재', 'name': '삼정펄프'},
#  {'code': '009200.KS', 'industry': '종이목재', 'name': '무림페이퍼'},
#  {'code': '004540.KS', 'industry': '종이목재', 'name': '깨끗한나라'},
#  {'code': '027970.KS', 'industry': '종이목재', 'name': '세하'},
#  {'code': '002300.KS', 'industry': '종이목재', 'name': '한국제지'},
#  {'code': '213500.KS', 'industry': '종이목재', 'name': '한솔제지'},
#  {'code': '016590.KS', 'industry': '종이목재', 'name': '신대양제지'},
#  {'code': '002870.KS', 'industry': '종이목재', 'name': '신풍제지'},
#  {'code': '009460.KS', 'industry': '종이목재', 'name': '한창제지'},
#  {'code': '002200.KS', 'industry': '종이목재', 'name': '수출포장'},
#  {'code': '012690.KS', 'industry': '종이목재', 'name': '모나리자'},
#  {'code': '011280.KS', 'industry': '종이목재', 'name': '태림포장'},
#  {'code': '001020.KS', 'industry': '종이목재', 'name': '페이퍼코리아'},
#  {'code': '002820.KS', 'industry': '종이목재', 'name': '선창산업'},
#  {'code': '006740.KS', 'industry': '종이목재', 'name': '영풍제지'},
#  {'code': '109070.KS', 'industry': '종이목재', 'name': '컨버즈'},
#  {'code': '002310.KS', 'industry': '종이목재', 'name': '아세아제지'},
#  {'code': '014160.KS', 'industry': '종이목재', 'name': '대영포장'},
#  {'code': '008250.KS', 'industry': '종이목재', 'name': '이건산업'},
#  {'code': '004545.KS', 'industry': '종이목재', 'name': '깨끗한나라우'},
#  {'code': '025750.KS', 'industry': '종이목재', 'name': '한솔홈데코'},
#  {'code': '003470.KS', 'industry': '증권', 'name': '유안타증권'},
#  {'code': '001200.KS', 'industry': '증권', 'name': '유진투자증권'},
#  {'code': '003475.KS', 'industry': '증권', 'name': '유안타증권우'},
#  {'code': '003465.KS', 'industry': '증권', 'name': '유화증권우'},
#  {'code': '001750.KS', 'industry': '증권', 'name': '한양증권'},
#  {'code': '003545.KS', 'industry': '증권', 'name': '대신증권우'},
#  {'code': '001515.KS', 'industry': '증권', 'name': 'SK증권우'},
#  {'code': '005945.KS', 'industry': '증권', 'name': 'NH투자증권우'},
#  {'code': '005940.KS', 'industry': '증권', 'name': 'NH투자증권'},
#  {'code': '039490.KS', 'industry': '증권', 'name': '키움증권'},
#  {'code': '016360.KS', 'industry': '증권', 'name': '삼성증권'},
#  {'code': '003540.KS', 'industry': '증권', 'name': '대신증권'},
#  {'code': '001275.KS', 'industry': '증권', 'name': '부국증권우'},
#  {'code': '001725.KS', 'industry': '증권', 'name': '신영증권우'},
#  {'code': '016610.KS', 'industry': '증권', 'name': 'DB금융투자'},
#  {'code': '003547.KS', 'industry': '증권', 'name': '대신증권2우B'},
#  {'code': '00680K.KS', 'industry': '증권', 'name': '미래에셋대우2'},
#  {'code': '001720.KS', 'industry': '증권', 'name': '신영증권'},
#  {'code': '001270.KS', 'industry': '증권', 'name': '부국증권'},
#  {'code': '030610.KS', 'industry': '증권', 'name': '교보증권'},
#  {'code': '006805.KS', 'industry': '증권', 'name': '미래에셋대우우'},
#  {'code': '001290.KS', 'industry': '증권', 'name': '골든브릿지증권'},
#  {'code': '001755.KS', 'industry': '증권', 'name': '한양증권우'},
#  {'code': '003530.KS', 'industry': '증권', 'name': '한화투자증권'},
#  {'code': '003535.KS', 'industry': '증권', 'name': '한화투자증권우'},
#  {'code': '001510.KS', 'industry': '증권', 'name': 'SK증권'},
#  {'code': '001500.KS', 'industry': '증권', 'name': '현대차증권'},
#  {'code': '006800.KS', 'industry': '증권', 'name': '미래에셋대우'},
#  {'code': '003460.KS', 'industry': '증권', 'name': '유화증권'},
#  {'code': '008560.KS', 'industry': '증권', 'name': '메리츠종금증권'},
#  {'code': '030210.KS', 'industry': '증권', 'name': 'KTB투자증권'},
#  {'code': '139480.KS', 'industry': '유통업', 'name': '이마트'},
#  {'code': '077500.KS', 'industry': '유통업', 'name': '유니퀘스트'},
#  {'code': '123690.KS', 'industry': '유통업', 'name': '한국화장품'},
#  {'code': '088790.KS', 'industry': '유통업', 'name': '진도'},
#  {'code': '002700.KS', 'industry': '유통업', 'name': '신일산업'},
#  {'code': '005440.KS', 'industry': '유통업', 'name': '현대그린푸드'},
#  {'code': '128820.KS', 'industry': '유통업', 'name': '대성산업'},
#  {'code': '010600.KS', 'industry': '유통업', 'name': '웰바이오텍'},
#  {'code': '000760.KS', 'industry': '유통업', 'name': '이화산업'},
#  {'code': '101140.KS', 'industry': '유통업', 'name': '아티스'},
#  {'code': '001745.KS', 'industry': '유통업', 'name': 'SK네트웍스우'},
#  {'code': '111770.KS', 'industry': '유통업', 'name': '영원무역'},
#  {'code': '005390.KS', 'industry': '유통업', 'name': '신성통상'},
#  {'code': '057050.KS', 'industry': '유통업', 'name': '현대홈쇼핑'},
#  {'code': '027390.KS', 'industry': '유통업', 'name': '한화갤러리아타'},
#  {'code': '138250.KS', 'industry': '유통업', 'name': '엔에스쇼핑'},
#  {'code': '004170.KS', 'industry': '유통업', 'name': '신세계'},
#  {'code': '001120.KS', 'industry': '유통업', 'name': 'LG상사'},
#  {'code': '027410.KS', 'industry': '유통업', 'name': 'BGF'},
#  {'code': '001740.KS', 'industry': '유통업', 'name': 'SK네트웍스'},
#  {'code': '047050.KS', 'industry': '유통업', 'name': '포스코대우'},
#  {'code': '067830.KS', 'industry': '유통업', 'name': '세이브존I&C'},
#  {'code': '004060.KS', 'industry': '유통업', 'name': 'SG세계물산'},
#  {'code': '069640.KS', 'industry': '유통업', 'name': '한세엠케이'},
#  {'code': '069960.KS', 'industry': '유통업', 'name': '현대백화점'},
#  {'code': '026960.KS', 'industry': '유통업', 'name': '동서'},
#  {'code': '093230.KS', 'industry': '유통업', 'name': '이아이디'},
#  {'code': '008600.KS', 'industry': '유통업', 'name': '윌비스'},
#  {'code': '002810.KS', 'industry': '유통업', 'name': '삼영무역'},
#  {'code': '004080.KS', 'industry': '유통업', 'name': '신흥'},
#  {'code': '071840.KS', 'industry': '유통업', 'name': '롯데하이마트'},
#  {'code': '005360.KS', 'industry': '유통업', 'name': '모나미'},
#  {'code': '023530.KS', 'industry': '유통업', 'name': '롯데쇼핑'},
#  {'code': '004270.KS', 'industry': '유통업', 'name': '남성'},
#  {'code': '011810.KS', 'industry': '유통업', 'name': 'STX'},
#  {'code': '013000.KS', 'industry': '유통업', 'name': '세우글로벌'},
#  {'code': '010420.KS', 'industry': '유통업', 'name': '한솔PNS'},
#  {'code': '008770.KS', 'industry': '유통업', 'name': '호텔신라'},
#  {'code': '008775.KS', 'industry': '유통업', 'name': '호텔신라우'},
#  {'code': '018670.KS', 'industry': '유통업', 'name': 'SK가스'},
#  {'code': '006370.KS', 'industry': '유통업', 'name': '대구백화점'},
#  {'code': '012170.KS', 'industry': '유통업', 'name': '키위미디어그룹'},
#  {'code': '037710.KS', 'industry': '유통업', 'name': '광주신세계'},
#  {'code': '001250.KS', 'industry': '유통업', 'name': 'GS글로벌'},
#  {'code': '000680.KS', 'industry': '유통업', 'name': 'LS네트웍스'},
#  {'code': '028260.KS', 'industry': '유통업', 'name': '삼성물산'},
#  {'code': '122900.KS', 'industry': '유통업', 'name': '아이마켓코리아'},
#  {'code': '081660.KS', 'industry': '유통업', 'name': '휠라코리아'},
#  {'code': '227840.KS', 'industry': '유통업', 'name': '현대코퍼레이션'},
#  {'code': '02826K.KS', 'industry': '유통업', 'name': '삼성물산우B'},
#  {'code': '009810.KS', 'industry': '유통업', 'name': '엔케이물산'},
#  {'code': '031430.KS', 'industry': '유통업', 'name': '신세계인터내셔'},
#  {'code': '017940.KS', 'industry': '유통업', 'name': 'E1'},
#  {'code': '011760.KS', 'industry': '유통업', 'name': '현대상사'},
#  {'code': '118000.KS', 'industry': '유통업', 'name': '우리들휴브레인'},
#  {'code': '009240.KS', 'industry': '유통업', 'name': '한샘'},
#  {'code': '282330.KS', 'industry': '유통업', 'name': 'BGF리테일'},
#  {'code': '007070.KS', 'industry': '유통업', 'name': 'GS리테일'},
#  {'code': '003010.KS', 'industry': '유통업', 'name': '혜인'},
#  {'code': '007110.KS', 'industry': '유통업', 'name': '일신석재'},
#  {'code': '005320.KS', 'industry': '유통업', 'name': '국동'},
#  {'code': '005110.KS', 'industry': '유통업', 'name': '한창'},
#  {'code': '002630.KS', 'industry': '소형주', 'name': '오리엔트바이오'},
#  {'code': '007540.KS', 'industry': '소형주', 'name': '샘표'},
#  {'code': '049800.KS', 'industry': '소형주', 'name': '우진플라임'},
#  {'code': '009310.KS', 'industry': '소형주', 'name': '참엔지니어링'},
#  {'code': '001360.KS', 'industry': '소형주', 'name': '삼성제약'},
#  {'code': '001340.KS', 'industry': '소형주', 'name': '백광산업'},
#  {'code': '003350.KS', 'industry': '소형주', 'name': '한국화장품제조'},
#  {'code': '248170.KS', 'industry': '소형주', 'name': '샘표식품'},
#  {'code': '006110.KS', 'industry': '소형주', 'name': '삼아알미늄'},
#  {'code': '011330.KS', 'industry': '소형주', 'name': '유니켐'},
#  {'code': '017960.KS', 'industry': '소형주', 'name': '한국카본'},
#  {'code': '077500.KS', 'industry': '소형주', 'name': '유니퀘스트'},
#  {'code': '009580.KS', 'industry': '소형주', 'name': '무림P&P'},
#  {'code': '005870.KS', 'industry': '소형주', 'name': '휴니드'},
#  {'code': '012030.KS', 'industry': '소형주', 'name': 'DB'},
#  {'code': '123690.KS', 'industry': '소형주', 'name': '한국화장품'},
#  {'code': '058850.KS', 'industry': '소형주', 'name': 'KTcs'},
#  {'code': '005090.KS', 'industry': '소형주', 'name': '삼광글라스'},
#  {'code': '145270.KS', 'industry': '소형주', 'name': '케이탑리츠'},
#  {'code': '044820.KS', 'industry': '소형주', 'name': '코스맥스비티아'},
#  {'code': '079660.KS', 'industry': '소형주', 'name': '사조해표'},
#  {'code': '009470.KS', 'industry': '소형주', 'name': '삼화전기'},
#  {'code': '005070.KS', 'industry': '소형주', 'name': '코스모신소재'},
#  {'code': '034300.KS', 'industry': '소형주', 'name': '신세계건설'},
#  {'code': '084870.KS', 'industry': '소형주', 'name': 'TBH글로벌'},
#  {'code': '088790.KS', 'industry': '소형주', 'name': '진도'},
#  {'code': '000040.KS', 'industry': '소형주', 'name': 'KR모터스'},
#  {'code': '007280.KS', 'industry': '소형주', 'name': '한국특수형강'},
#  {'code': '000850.KS', 'industry': '소형주', 'name': '화천기공'},
#  {'code': '012610.KS', 'industry': '소형주', 'name': '경인양행'},
#  {'code': '004250.KS', 'industry': '소형주', 'name': 'NPC'},
#  {'code': '063160.KS', 'industry': '소형주', 'name': '종근당바이오'},
#  {'code': '030720.KS', 'industry': '소형주', 'name': '동원수산'},
#  {'code': '002700.KS', 'industry': '소형주', 'name': '신일산업'},
#  {'code': '007660.KS', 'industry': '소형주', 'name': '이수페타시스'},
#  {'code': '058860.KS', 'industry': '소형주', 'name': '케이티스'},
#  {'code': '128820.KS', 'industry': '소형주', 'name': '대성산업'},
#  {'code': '000520.KS', 'industry': '소형주', 'name': '삼일제약'},
#  {'code': '010600.KS', 'industry': '소형주', 'name': '웰바이오텍'},
#  {'code': '007120.KS', 'industry': '소형주', 'name': '미래아이앤지'},
#  {'code': '016090.KS', 'industry': '소형주', 'name': '대현'},
#  {'code': '000760.KS', 'industry': '소형주', 'name': '이화산업'},
#  {'code': '007160.KS', 'industry': '소형주', 'name': '사조산업'},
#  {'code': '130660.KS', 'industry': '소형주', 'name': '한전산업'},
#  {'code': '006880.KS', 'industry': '소형주', 'name': '신송홀딩스'},
#  {'code': '101140.KS', 'industry': '소형주', 'name': '아티스'},
#  {'code': '000220.KS', 'industry': '소형주', 'name': '유유제약'},
#  {'code': '003960.KS', 'industry': '소형주', 'name': '사조대림'},
#  {'code': '071970.KS', 'industry': '소형주', 'name': 'STX중공업'},
#  {'code': '009180.KS', 'industry': '소형주', 'name': '한솔로지스틱스'},
#  {'code': '001940.KS', 'industry': '소형주', 'name': 'KISCO홀딩'},
#  {'code': '005390.KS', 'industry': '소형주', 'name': '신성통상'},
#  {'code': '001200.KS', 'industry': '소형주', 'name': '유진투자증권'},
#  {'code': '027390.KS', 'industry': '소형주', 'name': '한화갤러리아타'},
#  {'code': '003610.KS', 'industry': '소형주', 'name': '방림'},
#  {'code': '035510.KS', 'industry': '소형주', 'name': '신세계 I&C'},
#  {'code': '011420.KS', 'industry': '소형주', 'name': '갤럭시아에스엠'},
#  {'code': '016880.KS', 'industry': '소형주', 'name': '웅진'},
#  {'code': '001630.KS', 'industry': '소형주', 'name': '종근당홀딩스'},
#  {'code': '003480.KS', 'industry': '소형주', 'name': '한진중공업홀딩'},
#  {'code': '094280.KS', 'industry': '소형주', 'name': '효성ITX'},
#  {'code': '021820.KS', 'industry': '소형주', 'name': '세원정공'},
#  {'code': '002840.KS', 'industry': '소형주', 'name': '미원상사'},
#  {'code': '000890.KS', 'industry': '소형주', 'name': '보해양조'},
#  {'code': '005820.KS', 'industry': '소형주', 'name': '원림'},
#  {'code': '003680.KS', 'industry': '소형주', 'name': '한성기업'},
#  {'code': '214330.KS', 'industry': '소형주', 'name': '금호에이치티'},
#  {'code': '001130.KS', 'industry': '소형주', 'name': '대한제분'},
#  {'code': '016380.KS', 'industry': '소형주', 'name': '동부제철'},
#  {'code': '025000.KS', 'industry': '소형주', 'name': 'KPX케미칼'},
#  {'code': '068290.KS', 'industry': '소형주', 'name': '삼성출판사'},
#  {'code': '200880.KS', 'industry': '소형주', 'name': '서연이화'},
#  {'code': '102260.KS', 'industry': '소형주', 'name': '동성코퍼레이션'},
#  {'code': '001750.KS', 'industry': '소형주', 'name': '한양증권'},
#  {'code': '008110.KS', 'industry': '소형주', 'name': '대동전자'},
#  {'code': '000020.KS', 'industry': '소형주', 'name': '동화약품'},
#  {'code': '007340.KS', 'industry': '소형주', 'name': '디티알오토모티'},
#  {'code': '090350.KS', 'industry': '소형주', 'name': '노루페인트'},
#  {'code': '047400.KS', 'industry': '소형주', 'name': '유니온머티리얼'},
#  {'code': '001080.KS', 'industry': '소형주', 'name': '만호제강'},
#  {'code': '004360.KS', 'industry': '소형주', 'name': '세방'},
#  {'code': '004890.KS', 'industry': '소형주', 'name': '동일산업'},
#  {'code': '004100.KS', 'industry': '소형주', 'name': '태양금속'},
#  {'code': '078000.KS', 'industry': '소형주', 'name': '텔코웨어'},
#  {'code': '002140.KS', 'industry': '소형주', 'name': '고려산업'},
#  {'code': '005030.KS', 'industry': '소형주', 'name': '부산주공'},
#  {'code': '002460.KS', 'industry': '소형주', 'name': '화성산업'},
#  {'code': '075580.KS', 'industry': '소형주', 'name': '세진중공업'},
#  {'code': '024900.KS', 'industry': '소형주', 'name': '덕양산업'},
#  {'code': '001570.KS', 'industry': '소형주', 'name': '금양'},
#  {'code': '210540.KS', 'industry': '소형주', 'name': '디와이파워'},
#  {'code': '133820.KS', 'industry': '소형주', 'name': '화인베스틸'},
#  {'code': '019440.KS', 'industry': '소형주', 'name': '세아특수강'},
#  {'code': '084670.KS', 'industry': '소형주', 'name': '동양고속'},
#  {'code': '007690.KS', 'industry': '소형주', 'name': '국도화학'},
#  {'code': '015360.KS', 'industry': '소형주', 'name': '예스코홀딩스'},
#  {'code': '002420.KS', 'industry': '소형주', 'name': '세기상사'},
#  {'code': '144620.KS', 'industry': '소형주', 'name': '코오롱머티리얼'},
#  {'code': '011000.KS', 'industry': '소형주', 'name': '진원생명과학'},
#  {'code': '229640.KS', 'industry': '소형주', 'name': 'LS전선아시아'},
#  {'code': '003200.KS', 'industry': '소형주', 'name': '일신방직'},
#  {'code': '138490.KS', 'industry': '소형주', 'name': '코오롱플라스틱'},
#  {'code': '095720.KS', 'industry': '소형주', 'name': '웅진씽크빅'},
#  {'code': '004920.KS', 'industry': '소형주', 'name': '씨아이테크'},
#  {'code': '004700.KS', 'industry': '소형주', 'name': '조광피혁'},
#  {'code': '016710.KS', 'industry': '소형주', 'name': '대성홀딩스'},
#  {'code': '092220.KS', 'industry': '소형주', 'name': 'KEC'},
#  {'code': '037270.KS', 'industry': '소형주', 'name': 'YG PLUS'},
#  {'code': '002690.KS', 'industry': '소형주', 'name': '동일제강'},
#  {'code': '004150.KS', 'industry': '소형주', 'name': '한솔홀딩스'},
#  {'code': '033530.KS', 'industry': '소형주', 'name': '세종공업'},
#  {'code': '140910.KS', 'industry': '소형주', 'name': '에이리츠'},
#  {'code': '000140.KS', 'industry': '소형주', 'name': '하이트진로홀딩'},
#  {'code': '105840.KS', 'industry': '소형주', 'name': '우진'},
#  {'code': '005680.KS', 'industry': '소형주', 'name': '삼영전자'},
#  {'code': '282690.KS', 'industry': '소형주', 'name': '동아타이어'},
#  {'code': '036530.KS', 'industry': '소형주', 'name': 'S&T홀딩스'},
#  {'code': '100250.KS', 'industry': '소형주', 'name': '진양홀딩스'},
#  {'code': '089470.KS', 'industry': '소형주', 'name': 'HDC현대EP'},
#  {'code': '000540.KS', 'industry': '소형주', 'name': '흥국화재'},
#  {'code': '034590.KS', 'industry': '소형주', 'name': '인천도시가스'},
#  {'code': '005960.KS', 'industry': '소형주', 'name': '동부건설'},
#  {'code': '007860.KS', 'industry': '소형주', 'name': '서연'},
#  {'code': '008490.KS', 'industry': '소형주', 'name': '서흥'},
#  {'code': '003080.KS', 'industry': '소형주', 'name': '성보화학'},
#  {'code': '014580.KS', 'industry': '소형주', 'name': '백광소재'},
#  {'code': '006380.KS', 'industry': '소형주', 'name': '카프로'},
#  {'code': '268280.KS', 'industry': '소형주', 'name': '미원에스씨'},
#  {'code': '004840.KS', 'industry': '소형주', 'name': 'DRB동일'},
#  {'code': '014710.KS', 'industry': '소형주', 'name': '사조씨푸드'},
#  {'code': '013870.KS', 'industry': '소형주', 'name': '지엠비코리아'},
#  {'code': '003560.KS', 'industry': '소형주', 'name': 'IHQ'},
#  {'code': '009320.KS', 'industry': '소형주', 'name': '대우부품'},
#  {'code': '267290.KS', 'industry': '소형주', 'name': '경동도시가스'},
#  {'code': '010660.KS', 'industry': '소형주', 'name': '화천기계'},
#  {'code': '009440.KS', 'industry': '소형주', 'name': 'KC그린홀딩스'},
#  {'code': '082740.KS', 'industry': '소형주', 'name': 'HSD엔진'},
#  {'code': '009680.KS', 'industry': '소형주', 'name': '모토닉'},
#  {'code': '011700.KS', 'industry': '소형주', 'name': '한신기계'},
#  {'code': '006220.KS', 'industry': '소형주', 'name': '제주은행'},
#  {'code': '009070.KS', 'industry': '소형주', 'name': 'KCTC'},
#  {'code': '013570.KS', 'industry': '소형주', 'name': '디와이'},
#  {'code': '023450.KS', 'industry': '소형주', 'name': '동남합성'},
#  {'code': '023000.KS', 'industry': '소형주', 'name': '삼원강재'},
#  {'code': '002320.KS', 'industry': '소형주', 'name': '한진'},
#  {'code': '204210.KS', 'industry': '소형주', 'name': '모두투어리츠'},
#  {'code': '026890.KS', 'industry': '소형주', 'name': '디피씨'},
#  {'code': '009770.KS', 'industry': '소형주', 'name': '삼정펄프'},
#  {'code': '009200.KS', 'industry': '소형주', 'name': '무림페이퍼'},
#  {'code': '004540.KS', 'industry': '소형주', 'name': '깨끗한나라'},
#  {'code': '067830.KS', 'industry': '소형주', 'name': '세이브존I&C'},
#  {'code': '004060.KS', 'industry': '소형주', 'name': 'SG세계물산'},
#  {'code': '015020.KS', 'industry': '소형주', 'name': '이스타코'},
#  {'code': '069640.KS', 'industry': '소형주', 'name': '한세엠케이'},
#  {'code': '006890.KS', 'industry': '소형주', 'name': '태경화학'},
#  {'code': '009190.KS', 'industry': '소형주', 'name': '대양금속'},
#  {'code': '129260.KS', 'industry': '소형주', 'name': '인터지스'},
#  {'code': '069460.KS', 'industry': '소형주', 'name': '대호에이엘'},
#  {'code': '016610.KS', 'industry': '소형주', 'name': 'DB금융투자'},
#  {'code': '002170.KS', 'industry': '소형주', 'name': '삼양통상'},
#  {'code': '025530.KS', 'industry': '소형주', 'name': 'SJM홀딩스'},
#  {'code': '083370.KS', 'industry': '소형주', 'name': '동북아12호'},
#  {'code': '092230.KS', 'industry': '소형주', 'name': 'KPX홀딩스'},
#  {'code': '025560.KS', 'industry': '소형주', 'name': '미래산업'},
#  {'code': '003830.KS', 'industry': '소형주', 'name': '대한화섬'},
#  {'code': '083380.KS', 'industry': '소형주', 'name': '동북아13호'},
#  {'code': '005950.KS', 'industry': '소형주', 'name': '이수화학'},
#  {'code': '104700.KS', 'industry': '소형주', 'name': '한국철강'},
#  {'code': '172580.KS', 'industry': '소형주', 'name': '하이골드12호'},
#  {'code': '002710.KS', 'industry': '소형주', 'name': 'TCC동양'},
#  {'code': '003120.KS', 'industry': '소형주', 'name': '일성신약'},
#  {'code': '093230.KS', 'industry': '소형주', 'name': '이아이디'},
#  {'code': '006980.KS', 'industry': '소형주', 'name': '우성사료'},
#  {'code': '195870.KS', 'industry': '소형주', 'name': '해성디에스'},
#  {'code': '004080.KS', 'industry': '소형주', 'name': '신흥'},
#  {'code': '006090.KS', 'industry': '소형주', 'name': '사조오양'},
#  {'code': '010640.KS', 'industry': '소형주', 'name': '진양폴리'},
#  {'code': '023150.KS', 'industry': '소형주', 'name': 'MH에탄올'},
#  {'code': '111110.KS', 'industry': '소형주', 'name': '호전실업'},
#  {'code': '140890.KS', 'industry': '소형주', 'name': '트러스제7호'},
#  {'code': '140890.KS', 'industry': '소형주', 'name': '트러스제7호'},
#  {'code': '000860.KS', 'industry': '소형주', 'name': '강남제비스코'},
#  {'code': '001790.KS', 'industry': '소형주', 'name': '대한제당'},
#  {'code': '035000.KS', 'industry': '소형주', 'name': '지투알'},
#  {'code': '075180.KS', 'industry': '소형주', 'name': '새론오토모티브'},
#  {'code': '002360.KS', 'industry': '소형주', 'name': 'SH에너지화학'},
#  {'code': '027740.KS', 'industry': '소형주', 'name': '마니커'},
#  {'code': '000320.KS', 'industry': '소형주', 'name': '노루홀딩스'},
#  {'code': '017900.KS', 'industry': '소형주', 'name': '광전자'},
#  {'code': '011930.KS', 'industry': '소형주', 'name': '신성이엔지'},
#  {'code': '000950.KS', 'industry': '소형주', 'name': '전방'},
#  {'code': '002880.KS', 'industry': '소형주', 'name': '대유에이텍'},
#  {'code': '145210.KS', 'industry': '소형주', 'name': '세화아이엠씨'},
#  {'code': '003580.KS', 'industry': '소형주', 'name': '넥스트사이언스'},
#  {'code': '008600.KS', 'industry': '소형주', 'name': '윌비스'},
#  {'code': '014130.KS', 'industry': '소형주', 'name': '한익스프레스'},
#  {'code': '015890.KS', 'industry': '소형주', 'name': '태경산업'},
#  {'code': '002920.KS', 'industry': '소형주', 'name': '유성기업'},
#  {'code': '024890.KS', 'industry': '소형주', 'name': '대원화성'},
#  {'code': '002600.KS', 'industry': '소형주', 'name': '조흥'},
#  {'code': '002990.KS', 'industry': '소형주', 'name': '금호산업'},
#  {'code': '079980.KS', 'industry': '소형주', 'name': '휴비스'},
#  {'code': '011150.KS', 'industry': '소형주', 'name': 'CJ씨푸드'},
#  {'code': '004970.KS', 'industry': '소형주', 'name': '신라교역'},
#  {'code': '234080.KS', 'industry': '소형주', 'name': 'JW생명과학'},
#  {'code': '011160.KS', 'industry': '소형주', 'name': '두산건설'},
#  {'code': '000970.KS', 'industry': '소형주', 'name': '한국주철관'},
#  {'code': '015230.KS', 'industry': '소형주', 'name': '대창단조'},
#  {'code': '155660.KS', 'industry': '소형주', 'name': 'DSR'},
#  ...]

# %%
import json 
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
from datetime import datetime as dt
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt 
with open('companyList.json') as data_file:    
    company_lst = json.load(data_file) 
def parse_code(x):
    x['code'] = x['code'].split('?code=')[1] + '.KS'
    return x

def find_industry(indust,company_lst):
    return list(filter(lambda x: x['industry']==indust,company_lst))
    
company_lst = list(map(parse_code,company_lst))
tele_lst = find_industry('통신업',company_lst)
start = dt(1995,1,3)
end = dt.now()
df = pdr.get_data_yahoo(list(set([x['code'] for x in tele_lst])), start=start, end=end)
df =df['Adj Close']

col_dict = { x['code']:x['name']for x in tele_lst}
df = df.rename(columns=col_dict)

# %%
df.plot()
plt.show()

# %%
df.columns = ['inscobi','sktelecom','kt','lguplus']
interest_df = pd.read_csv('./interests_data.csv')
interest_df = interest_df.set_index('date')
interest_df.index = pd.to_datetime(interest_df.index, format = '%Y%m%d')

merge=df.merge(interest_df, how='inner', left_index=True, right_index=True)

# %%
merge = merge.rename(columns={'회사채(3년,AA-)':'interest_rate'})
merge['interest_rate'] = merge['interest_rate'].shift(1)
merge_norm = (merge -merge.mean())/merge.std()
merge_norm = merge_norm.drop(['Unnamed: 0'],axis=1)
merge_norm.plot()

# %% [markdown]
# #  건설업데이터가져오기

# %%
manu_lst = find_industry('건설업',company_lst)
start = dt(2010,1,1)
end = dt.now()
df = pdr.get_data_yahoo(sorted(list(set([x['code'] for x in manu_lst])))[:15], start=start, end=end)
df =df['Adj Close']

col_dict = { x['code']:x['name']for x in manu_lst}
df = df.rename(columns=col_dict)

# %%
merge=df.merge(interest_df, how='inner', left_index=True, right_index=True)
merge = merge.rename(columns={'회사채(3년,AA-)':'interest_rate'})
merge = merge.drop(['Unnamed: 0'],axis=1)

# %%
merge[:4].to_csv('test_interest.csv')
